# %%
import json
import requests
from pprint import pprint
import difflib
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from datetime import datetime

# %%
with open('data.json') as json_data:
    d = json.load(json_data)
    data = d

# %%
len(data)
# Out:
# 15

# %%
documents = {'documents' : []}
other_docs = {'documents': []}

for store in data:
    text = ''
    for i in store['reviews']:
        text += i[0]
        
    if(len(text) > 5120):
        done = False
        start = 0
        iteration = 0
        while(start < len(text)):
            end = start + 5120
            if(end >= len(text)):
                end = len(text)
            print(start, end)
            documents['documents'].append({'id': store['id'] +';' + str(iteration), 'language': 'en',
                                   'text': text[start: end]})
            iteration+=1
            start = end
    else:
        documents['documents'].append({'id': store['id'], 'language': 'en', 'text': text})
    
    other_docs['documents'].append({'id': store['id'], 'language': 'en', 'text': text})
    
    print('finished store')
# Out:
# 0 5120
# 5120 10240
# 10240 13980
# finished store
# 0 5120
# 5120 10240
# 10240 12342
# finished store
# 0 5120
# 5120 10240
# 10240 10635
# finished store
# 0 5120
# 5120 5270
# finished store
# finished store
# finished store
# 0 5120
# 5120 7745
# finished store
# finished store
# finished store
# finished store
# finished store
# finished store
# finished store
# finished store
# finished store

# %%
def getPopularPhones(business_id):
    pop_phones = []
    
    for store in key_phrases['documents']:
        if(business_id in store['id']):
            phones = {
                'samsung': [
                    's9',
                    's8',
                    's7',
                    'note',
                    's6', 
                ],
                'apple': ['iphone', 'ipad', 'ipod'],
                'motorola': ['motoX'],
                'google': ['Nexus'],
                'LG': ['g9', 'g5', 'g6', 'g3', 'g4'],
            }

            phrases = store['keyPhrases']
            frequencies = {}
            for word in phrases:
                for brand,v in phones.items():
                    for phone in v:
                        seq = difflib.SequenceMatcher(None,word.lower(),phone)
                        d = seq.ratio()*100
                        if(d > 0.75):
                            largest = None
                            smallest = None
                            if(len(phone) > len(word)):
                                largest = phone
                                smallest = word
                            else:
                                largest = word
                                smallest = phone

                            if(smallest.lower() in largest.lower()):
                                if(brand in frequencies.keys()):
                                    frequencies[phone] += 1
                                else:
                                    frequencies[phone] = 1
    return frequencies


text_analytics_base_url = "https://eastus.api.cognitive.microsoft.com/text/analytics/v2.0"
key_phrase_api_url = text_analytics_base_url + "/keyPhrases"

headers   = {'Ocp-Apim-Subscription-Key': '5c0a1002f18a454c9ebadfe86b72964f'}
response  = requests.post(key_phrase_api_url, headers=headers, json=documents)
key_phrases = response.json()

#print(key_phrases['documents'])
#print(getPopularPhones('N_v0tMRmqgTnnusrcVI3dw'))
for i in key_phrases['documents']:
    print(getPopularPhones(i['id']), i['id'])
# Out:
# {} wKKRoSg1pZQtQRYPoD7TXg;0
# {} wKKRoSg1pZQtQRYPoD7TXg;1
# {'iphone': 1} wKKRoSg1pZQtQRYPoD7TXg;2
# {} 8hXzJzOb3K1eFor0oNrPWA;0
# {} 8hXzJzOb3K1eFor0oNrPWA;1
# {'iphone': 1, 'note': 1} 8hXzJzOb3K1eFor0oNrPWA;2
# {'s7': 1, 'iphone': 1, 'note': 1} z-ldpf_9VxZjITfBb7Lnkg;0
# {'Nexus': 1} z-ldpf_9VxZjITfBb7Lnkg;1
# {} z-ldpf_9VxZjITfBb7Lnkg;2
# {'s6': 1, 'iphone': 1} qiAckHMVZQScy2U9nvSCmQ;0
# {} qiAckHMVZQScy2U9nvSCmQ;1
# {'iphone': 1} 9oHGS1knSS3uAHsf2sqxRg
# {'iphone': 1} oKrbc2dBvop1eo4dwdGk6Q
# {'iphone': 1} GP2c4RUrfCPivCTVZ_VueA;0
# {} GP2c4RUrfCPivCTVZ_VueA;1
# {'s6': 1, 'iphone': 1} ZgkdwRzfT2QjQbzi34t96A
# {'iphone': 1} N_v0tMRmqgTnnusrcVI3dw
# {'iphone': 1, 'Nexus': 1} EGHoMbnG-vzwotSQz9oeqQ
# {} 8XBfdAwp1Y_IrhFdSZaNzw
# {'iphone': 1} Qh0Z1gyxugwZzAna4UsCKA
# {} sSc4MPlUOPCEXEDQw_DISg
# {'motoX': 1} jMCpYt9N6VqtjS-U2ubjZQ
# {'note': 1} RlaaCtbydgyg8ItxIeuFRQ

# %%
import json
import os
import nltk
from nltk import FreqDist
import pandas as pd
import matplotlib.pyplot as plt
import re
import requests
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
import time

subscription_key = '5c0a1002f18a454c9ebadfe86b72964f'  # os.environ['MS_KEY']
assert subscription_key
text_analytics_base_url = "https://westcentralus.api.cognitive.microsoft.com/text/analytics/v2.0/"

class StoreDB:
    def __init__(self):
        self.df = pd.read_json('../datascraper/data.json', dtype=object)
        self.df = self.df.set_index('name')
        self.df['agg_sent'] = 0.0
        self.df['sentiments'] = None
        self.df['time'] = None
        self.df['sentiments'] = self.df['sentiments'].astype(object)
        self.df['key_phrases_pos'] = None
        self.df['key_phrases_pos'] = self.df['key_phrases_pos'].astype(object)
        self.df['key_phrases_neg'] = None
        self.df['key_phrases_neg'] = self.df['key_phrases_neg'].astype(object)
        for index, row in self.df.iterrows():
            idnum = 0
            docDic = []
            times = []
            for rev in self.df.loc[index]['reviews']:
                docDic.append({'id':idnum, 'language':'en', 'text': rev[0]})
                times.append([rev[1], datetime.strptime(rev[2].rstrip().lstrip(), "%m/%d/%Y")])
                idnum += 1
            
            self.df.at[index, 'time'] = times
            
            documents = {'documents' : docDic}
            headers   = {'Ocp-Apim-Subscription-Key': subscription_key}
            sentiment_api_url = text_analytics_base_url + "sentiment"
            response  = requests.post(sentiment_api_url, headers=headers, json=documents)
            sentiments = response.json()
            sent_scores = []
            pos_docs = []
            neg_docs = []
            try:
                for doc in sentiments['documents']:
                    val = doc['score']
                    if val > 0.5:
                        pos_docs.append(doc['id'])
                    else:
                        neg_docs.append(doc['id'])
                    sent_scores.append(doc['score'])
            except:
                print(documents)
                print(sentiments)
            self.df.at[index, 'agg_sent'] = sum(sent_scores) / float(len(sent_scores))
            self.df.at[index, 'sentiments'] = sentiments['documents']

            key_phrase_api_url = text_analytics_base_url + "keyPhrases"
            headers   = {'Ocp-Apim-Subscription-Key': subscription_key}
            response  = requests.post(key_phrase_api_url, headers=headers, json=documents)
            key_phrases = response.json()
            pos_phrases = []
            neg_phrases = []
            for doc in key_phrases['documents']:
                if doc['id'] in pos_docs:
                    pos_phrases.append(doc)
                elif doc['id'] in neg_docs:
                    neg_phrases.append(doc)
                    

            self.df.at[index, 'key_phrases_pos'] = pos_phrases
            self.df.at[index, 'key_phrases_neg'] = neg_phrases

    def key_phrases_pos(self, store):
        pos_phrases = self.df.loc[store]['key_phrases_pos']
        return pos_phrases
    
    def key_phrases_neg(self, store):
        neg_phrases = self.df.loc[store]['key_phrases_neg']
        return neg_phrases 

    def get_raw_reviews(self, store):
        raw_revs = self.df.loc[store]['reviews']
        return raw_revs
    
    def get_agg_sent(self, store):
        return self.df.loc[store]['aggSent']

# %%
db = StoreDB()
# Out:
# {'documents': [{'language': 'en', 'id': 0, 'text': "Was in town for work and had issues with my phone and service. This T-mobile is one of the earliest one to open; and they're right at midtown, so I went in right at 9am. The customer service reps were knowledgeable and friendly. They helped me fixed my issues and also recommended great restaurants for my meeting (off topic). Thank you!! Ps- 5Church was a great suggestion. Thanks again!"}, {'language': 'en', 'id': 1, 'text': "I came here to do an upgrade about two months ago. There really wasn't anyone there, it was quiet, the place was well organized and the associates were very helpful through the upgrade process. Although, I had a bit of trouble trying to get my new device, #TeamMagenta was there to answer any questions that I may have had. I'll be going here from now on to do any upgrades!!!"}, {'language': 'en', 'id': 2, 'text': "I walked in to upgrade my phone and asked how long it would take to make the transfer of my backed up data. I was told 10-15 minutes. The girl helping me was texting while helping me and didn't know what she was doing. She screwed up the transfer 4 times until I asked a manager to help. He didn't know what he was doing either and by the time we got out of the store it took 1.5 hours. Terrible service, I am extremely unsatisfied and would NOT recommend coming to this location. If you want better service hopefully there's a better T-mobile location that actually knows what they are doing."}, {'language': 'en', 'id': 3, 'text': "Maybe I got lucky, but my rep, a young man named 'Houston' was not only super friendly, but hooked me up in a flash. \xa0Very friendly and accommodated my needs extremely well."}, {'language': 'en', 'id': 4, 'text': 'I called today asking if a certain promotion still exists. The customer representative on the line said,"No, it ended yesterday. Bye." Bye. Really? It would have been courteous if she asked if I had any other questions (which in fact I did). Very rude.'}, {'language': 'en', 'id': 5, 'text': "I had two awful experiences from two different locations. The one located inside Cumberland mall, sold me things I already told I don't need and now, I have a second line that can't be removed. The second location was Tmobile at 5th street, where I thought this guy made sure to add my insurance back on. 6 months later, I found out he never did. Luckily, the phone was still under warranty. I was so close to shopping for a different carrier after being a loyal T-mobile customer for 14 yrs until I met Jamin and Whitney. Both spent almost an hour with me on 2 different issues that they had to correct because of some idiot & incompetent former employee. If I could just reach their managers and asked that they should be recognized for their 5-star stellar customer service performance...!"}, {'language': 'en', 'id': 6, 'text': "Short version: Slow, inefficient. \xa0Avoid unless you enjoy waiting.Long version: \xa0I came in around 11:40 to get a sim card for a phone I had purchased elsewhere. \xa0There wasn't a line per se...just a collection of individuals around the store - maybe 3 people ahead of me though. \xa0Around 30 minutes later I'm 'next' in 'line.' \xa0The clerk at this point decides to help both myself and the lady she was working with simultaneously. \xa0I normally applaud this sort of multi-tasking...but it was done so badly and so rudely that she really should not have bothered.Another 15 minutes go by, during most of which I'm not entirely sure if my new sim card is being acquired or not.Finally I'm handed a sim card and told to try it out - I'm done.The sim card was free due to the wait I experienced - which is why this review is 2 stars instead of 1."}, {'language': 'en', 'id': 7, 'text': 'This store needs some new management and staff. Seems like T-Mobile is hiring uneducated delinquents off the streets.. No one is knowledgeable about current products or current offers. For having a good location this place sucks  ...
# {'message': 'Rate limit is exceeded. Try again in 15 seconds.', 'statusCode': 429}
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-154-2703663f0ab5> in <module>()
# ----> 1 db = StoreDB()
#
# <ipython-input-153-cb47dbad347b> in __init__(self)
#      58                 print(documents)
#      59                 print(sentiments)
# ---> 60             self.df.at[index, 'agg_sent'] = sum(sent_scores) / float(len(sent_scores))
#      61             self.df.at[index, 'sentiments'] = sentiments['documents']
#      62
#
# ZeroDivisionError: float division by zero

# %%
db.df.loc['t-mobile-atlanta-13']['time']
# Out:
# [[5.0, '1/29/2019'],
#  [5.0, '11/8/2018'],
#  [1.0, '2/12/2017'],
#  [5.0, '12/29/2016'],
#  [1.0, '6/29/2016'],
#  [5.0, '5/13/2017'],
#  [2.0, '12/11/2015'],
#  [1.0, '5/8/2016'],
#  [1.0, '7/12/2013'],
#  [1.0, '4/15/2014'],
#  [1.0, '10/11/2014'],
#  [2.0, '3/8/2011'],
#  [5.0, '7/2/2008'],
#  [1.0, '10/13/2014'],
#  [3.0, '6/2/2010'],
#  [1.0, '6/8/2014'],
#  [2.0, '5/20/2014'],
#  [2.0, '1/13/2009']]

# %%
from math import pi

import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.palettes import Category20c, viridis
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.palettes import Spectral6
from bokeh.models import ColumnDataSource

# %%
class GraphicsLib:
    def __init__(self, business):
        text_analytics_base_url = "https://eastus.api.cognitive.microsoft.com/text/analytics/v2.0"
        key_phrase_api_url = text_analytics_base_url + "/keyPhrases"

        headers   = {'Ocp-Apim-Subscription-Key': '5c0a1002f18a454c9ebadfe86b72964f'}
        response  = requests.post(key_phrase_api_url, headers=headers, json=documents)
        self.key_phrases = response.json()
        self.id = business
        self.sid = SentimentIntensityAnalyzer()
        
    def getPopularPhones(self):
        pop_phones = []
        
        business_id = self.id
        for store in self.key_phrases['documents']:
            if(business_id in store['id']):
                phones = {
                    'samsung': [
                        's9',
                        's8',
                        's7',
                        'note',
                        's6', 
                    ],
                    'apple': ['iphone', 'ipad', 'ipod'],
                    'motorola': ['motoX'],
                    'google': ['Nexus'],
                    'LG': ['g9', 'g5', 'g6', 'g3', 'g4'],
                }

                phrases = store['keyPhrases']
                frequencies = {}
                for word in phrases:
                    for brand,v in phones.items():
                        for phone in v:
                            seq = difflib.SequenceMatcher(None,word.lower(),phone)
                            d = seq.ratio()*100
                            if(d > 0.75):
                                largest = None
                                smallest = None
                                if(len(phone) > len(word)):
                                    largest = phone
                                    smallest = word
                                else:
                                    largest = word
                                    smallest = phone

                                if(smallest.lower() in largest.lower()):
                                    if(brand in frequencies.keys()):
                                        frequencies[phone] += 1
                                    else:
                                        frequencies[phone] = 1
        return frequencies
    
    def getServiceSentiment(self):
        business_id = self.id
        sentiment = {'pos': [0, []], 'neg': [0, []], 'neutral': [0, []]}
        for store in self.key_phrases['documents']:
            if(business_id in store['id']):
                phrases = store['keyPhrases']
                frequencies = {}
                phones = ['customer', 'service']
                for phone in phones:
                    for word in phrases:
                        seq = difflib.SequenceMatcher(None,word.lower(),phone)
                        d = seq.ratio()*100
                        if(d > 0.75):
                            largest = None
                            smallest = None
                            if(len(phone) > len(word)):
                                largest = phone
                                smallest = word
                            else:
                                largest = word
                                smallest = phone

                            if(smallest.lower() in largest.lower()):
                                polarity = self.sid.polarity_scores(largest)['compound']
                                if(polarity == 0.0):
                                    sentiment['neutral'][0] += 1
                                    sentiment['neutral'][1].append(largest)
                                elif(polarity < 0.0):
                                    sentiment['neg'][0] += 1
                                    sentiment['neg'][1].append(largest)
                                else:
                                    sentiment['pos'][0] += 1
                                    sentiment['pos'][1].append(largest)
                                    
        return sentiment
                    
    def getPhoneChart(self):
        x = self.getPopularPhones()
        
        data = pd.Series(x).reset_index(name='value').rename(columns={'index':'models'})
        data['angle'] = data['value']/data['value'].sum() * 2*pi
        data['color'] = viridis(len(x))

        p = figure(plot_height=350, title="Phone useage in Store %s" % (store_id), toolbar_location=None,
                   tools="hover", tooltips="@models: @value", x_range=(-0.5, 1.0))

        p.wedge(x=0, y=1, radius=0.4,
                start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
                line_color="white", fill_color='color', legend='models', source=data)

        p.axis.axis_label=None
        p.axis.visible=False
        p.grid.grid_line_color = None

        output_notebook()
        show(p)
        
    def getServiceSentimentChart(self):
        x = self.getServiceSentiment()

        source = ColumnDataSource(data=dict(sentiment= list(x.keys()), counts= [v[0] for k,v in x.items()],
                                            color=Spectral6, services = [';'.join(v[1]) for k,v in x.items()]))

        p = figure(x_range = list(x.keys()), title="Service Sentiment for %s" % (self.id),
                   toolbar_location=None, tools="hover", tooltips="@sentiment: @services")

        p.vbar(x='sentiment', top='counts', width=0.9, color='color', source=source)

        p.xgrid.grid_line_color = None
        
        output_notebook()
        show(p)
        
    def returnData(self):
        return self.key_phrases
    
    def getStoreIds(self):
        return list(map(lambda x: x['id'], self.returnData()['documents']))

# %%
class ChefJeff:
    def __init__(self, db, business):
        self.db = db
        self.id = business
        self.sid = SentimentIntensityAnalyzer()
        
    def getPopularPhones(self):
        pop_phones = []
        phones = {
                    'samsung': [
                        's9',
                        's8',
                        's7',
                        'note',
                        's6', 
                    ],
                    'apple': ['iphone', 'ipad', 'ipod'],
                    'motorola': ['motoX'],
                    'google': ['Nexus'],
                    'LG': ['g9', 'g5', 'g6', 'g3', 'g4'],
                }
        frequencies = {}
        
        business_id = self.id
        data = self.db.df.loc[business_id]
        for category in ['key_phrases_pos', 'key_phrases_neg']:
            for dictionary in data[category]:
                for word in dictionary['keyPhrases']:
                    for brand,v in phones.items():
                        for phone in v:
                            seq = difflib.SequenceMatcher(None,word.lower(),phone)
                            d = seq.ratio()*100
                            if(d > 0.75):
                                largest = None
                                smallest = None
                                if(len(phone) > len(word)):
                                    largest = phone
                                    smallest = word
                                else:
                                    largest = word
                                    smallest = phone

                                if(smallest.lower() in largest.lower()):
                                    if(brand in frequencies.keys()):
                                        frequencies[phone] += 1
                                    else:
                                        frequencies[phone] = 1
        return frequencies
    
    def getServiceSentiment(self):
        sentiment = {'pos': [0, []], 'neg': [0, []], 'neutral': [0, []]}
        
        business_id = self.id
        data = self.db.df.loc[business_id]
        for category in ['key_phrases_pos', 'key_phrases_neg']:
            for dictionary in data[category]:
                phones = ['customer', 'service']
                for phone in phones:
                    for word in dictionary['keyPhrases']:
                        seq = difflib.SequenceMatcher(None,word.lower(),phone)
                        d = seq.ratio()*100
                        if(d > 0.75):
                            largest = None
                            smallest = None
                            if(len(phone) > len(word)):
                                largest = phone
                                smallest = word
                            else:
                                largest = word
                                smallest = phone

                            if(smallest.lower() in largest.lower()):
                                polarity = self.sid.polarity_scores(largest)['compound']
                                if(polarity == 0.0):
                                    sentiment['neutral'][0] += 1
                                    sentiment['neutral'][1].append(largest)
                                elif(polarity < 0.0):
                                    sentiment['neg'][0] += 1
                                    sentiment['neg'][1].append(largest)
                                else:
                                    sentiment['pos'][0] += 1
                                    sentiment['pos'][1].append(largest)
                                    
        return sentiment
                    
    def getPhoneChart(self):
        x = self.getPopularPhones()
        
        data = pd.Series(x).reset_index(name='value').rename(columns={'index':'models'})
        data['angle'] = data['value']/data['value'].sum() * 2*pi
        data['color'] = viridis(len(x))

        p = figure(plot_height=350, title="Phone useage in Store %s" % (store_id), toolbar_location=None,
                   tools="hover", tooltips="@models: @value", x_range=(-0.5, 1.0))

        p.wedge(x=0, y=1, radius=0.4,
                start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
                line_color="white", fill_color='color', legend='models', source=data)

        p.axis.axis_label=None
        p.axis.visible=False
        p.grid.grid_line_color = None

        output_notebook()
        show(p)
        
    def getServiceSentimentChart(self):
        x = self.getServiceSentiment()

        source = ColumnDataSource(data=dict(sentiment= list(x.keys()), counts= [v[0] for k,v in x.items()],
                                            color=Spectral6, services = [';'.join(v[1]) for k,v in x.items()]))

        p = figure(x_range = list(x.keys()), title="Service Sentiment for %s" % (self.id),
                   toolbar_location=None, tools="hover", tooltips="@sentiment: @services")

        p.vbar(x='sentiment', top='counts', width=0.9, color='color', source=source)

        p.xgrid.grid_line_color = None
        
        output_notebook()
        show(p)
        
    def returnData(self):
        return self.key_phrases
    
    def getStoreIds(self):
        return list(map(lambda x: x['id'], self.returnData()['documents']))

# %%
a = ChefJeff(db, 't-mobile-atlanta-3')
a.getPhoneChart()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5752">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ca5dbeba-21d3-4452-9f59-587360884a40" data-root-id="5714"></div>

# %%
a = GraphicsLib('z-ldpf_9VxZjITfBb7Lnkg')
a.getServiceSentimentChart()
print(a.getStoreIds())
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('color', 6), ('counts', 3), ('sentiment', 3), ('services', 3)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5227">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a95ffc27-bea1-4d44-871a-222b0e093c7e" data-root-id="5200"></div>
# ['wKKRoSg1pZQtQRYPoD7TXg;0', 'wKKRoSg1pZQtQRYPoD7TXg;1', 'wKKRoSg1pZQtQRYPoD7TXg;2', '8hXzJzOb3K1eFor0oNrPWA;0', '8hXzJzOb3K1eFor0oNrPWA;1', '8hXzJzOb3K1eFor0oNrPWA;2', 'z-ldpf_9VxZjITfBb7Lnkg;0', 'z-ldpf_9VxZjITfBb7Lnkg;1', 'z-ldpf_9VxZjITfBb7Lnkg;2', 'qiAckHMVZQScy2U9nvSCmQ;0', 'qiAckHMVZQScy2U9nvSCmQ;1', '9oHGS1knSS3uAHsf2sqxRg', 'oKrbc2dBvop1eo4dwdGk6Q', 'GP2c4RUrfCPivCTVZ_VueA;0', 'GP2c4RUrfCPivCTVZ_VueA;1', 'ZgkdwRzfT2QjQbzi34t96A', 'N_v0tMRmqgTnnusrcVI3dw', 'EGHoMbnG-vzwotSQz9oeqQ', '8XBfdAwp1Y_IrhFdSZaNzw', 'Qh0Z1gyxugwZzAna4UsCKA', 'sSc4MPlUOPCEXEDQw_DISg', 'jMCpYt9N6VqtjS-U2ubjZQ', 'RlaaCtbydgyg8ItxIeuFRQ']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Sachin
# [nltk_data]     Konan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize 
  
def tokenize(text):
    return word_tokenize(text)

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Sachin
# [nltk_data]     Konan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Sachin
# [nltk_data]     Konan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
import random
text_data = []

for i in range(0, len(other_docs['documents'])):
    string = other_docs['documents'][i]['text']
    tokens = prepare_text_for_lda(string)
    if random.random() > .75:
        print(tokens)
        text_data.append(tokens)
        
print(text_data)
# Out:
# ['issue', 'phone', 'service', 'T-mobile', 'earliest', 'right', 'midtown', 'right', 'customer', 'service', 'knowledgeable', 'friendly', 'help', 'fix', 'issue', 'recommend', 'great', 'restaurant', 'meeting', 'topic', 'Thank', '5Church', 'great', 'suggestion', 'Thanks', 'upgrade', 'month', 'There', 'really', 'anyone', 'quiet', 'place', 'organize', 'associate', 'helpful', 'upgrade', 'process', 'Although', 'trouble', 'try', 'device', 'TeamMagenta', 'answer', 'question', 'going', 'upgrade', 'walk', 'upgrade', 'phone', 'ask', 'would', 'transfer', 'back', '10-15', 'minutes', 'helping', 'texting', 'helping', 'screw', 'transfer', 'times', 'ask', 'manager', 'either', 'store', 'hours', 'Terrible', 'service', 'extremely', 'unsatisfied', 'would', 'recommend', 'coming', 'location', 'better', 'service', 'hopefully', 'better', 'T-mobile', 'location', 'actually', 'know', 'doing.Maybe', 'lucky', 'young', 'name', "'Houston", 'super', 'friendly', 'hook', 'flash', 'friendly', 'accommodate', 'need', 'extremely', 'well.I', 'call', 'today', 'asking', 'certain', 'promotion', 'still', 'exist', 'customer', 'representative', 'end', 'yesterday', 'Really', 'would', 'courteous', 'ask', 'question', 'rude.I', 'awful', 'experience', 'different', 'location', 'locate', 'inside', 'Cumberland', 'things', 'already', 'second', 'remove', 'second', 'location', 'Tmobile', 'street', 'thought', 'insurance', 'month', 'later', 'found', 'never', 'Luckily', 'phone', 'still', 'warranty', 'close', 'shopping', 'different', 'carrier', 'loyal', 'T-mobile', 'customer', 'Jamin', 'Whitney', 'spend', 'almost', 'different', 'issue', 'correct', 'idiot', 'incompetent', 'former', 'employee', 'could', 'reach', 'manager', 'ask', 'recognize', '5-star', 'stellar', 'customer', 'service', 'performance', 'Short', 'version', 'inefficient', 'Avoid', 'unless', 'enjoy', 'waiting.Long', 'version', 'around', '11:40', 'phone', 'purchase', 'elsewhere', 'There', 'collection', 'individual', 'around', 'store', 'maybe', 'people', 'ahead', 'though', 'Around', 'minutes', 'later', "'next", "'line", 'clerk', 'point', 'decide', 'working', 'simultaneously', 'normally', 'applaud', 'multi-tasking', 'badly', 'rudely', 'really', 'bothered.Another', 'minutes', 'entirely', 'acquire', 'not.Finally', 'hand', 'done.The', 'experience', 'review', 'star', 'instead', '1.This', 'store', 'need', 'management', 'staff', 'Seems', 'T-Mobile', 'hire', 'uneducated', 'delinquent', 'streets..', 'knowledgeable', 'current', 'product', 'current', 'offer', 'location', 'place', 'suck', 'return', 'unless', 'major', 'change', 'made.Worst', 'T-mobile', 'Store', 'Horrible', 'service', 'attitude', 'Whether', 'people', 'right', 'bitter', 'angry', 'always', 'experience', 'second', 'chance', 'T-Mobile', 'pride', 'awesome', 'service', 'family', 'stick', 'decade', 'store', 'store', 'attitude', 'leaf', 'taste', 'mouth', 'never', 'enough', 'employee', 'handle', 'amount', 'customer', 'There', 'literally', 'associate', 'juggling', 'juggling', 'people', 'person', 'unable', 'multitask', 'could', 'literally', 'standing', 'queue', 'minutes', 'There', 'caveat', 'though', 'friend', 'certain', 'customer', 'everything', 'attend', 'Unless', 'President', 'Obama', 'First', 'Michelle', 'maybe', 'Oprah', 'attend', 'customer', 'order', 'appear', 'literally', 'three', 'people', 'Barack', 'Michelle', 'Oprah', 'attend', 'customer', 'order', 'arrival', 'mention', 'almost', 'ALWAYS', 'phone', 'hardly', 'new', 'phone', 'stock', 'center', 'literally', 'Peachtree', 'Street', 'phone', 'stock', 'cherry', 'PARKING', 'LIMITED', 'LIMITED', '*sigh*', 'Please', 'better', 'store', 'make', 'T-mobile', 'bad.Worst', 'tmobile', 'store', 'tmobile', 'customer', 'years', 'going', 'store', 'tempt', 'switch', 'carrier', 'specific', 'store', 'times', 'worst', 'customer', 'service', 'experience', 'texting', 'try', 'question', 'another', 'close', 'store', 'schedule', 'ignore', 'worker', 'friend', 'talking', 'weekend', 'assist', 'me.Yep', 'review', 'consistent', 'customer', 'service', 'visiting', ...
# ['customer', 'service', 'chart', 'staff', 'beyond', 'great', 'experience', 'Where', 'worker', 'something', 'absolutely', 'ridiculous', 'manage', 'store', 'he/she', 'replace', 'Complaint', 'complaint', 'waiting', 'times', 'thing', 'clear', 'care.I', 'T-Mobile', 'customer', 'years', 'always', 'impress', 'product', 'quality', 'face-to-face', 'member', 'story', 'always', 'impress', 'second', 'location', 'never', 'experience', 'service', 'Thomas', 'store', 'manager', 'beyond', 'experience', 'could', 'educate', 'devices', 'provide', 'current', 'offer', 'Samsung', 'T-Mobile', 'another', 'store', 'tablet', 'stock', 'location', 'blow', 'customer', 'service', 'location', 'tight', 'light', 'professional', 'attitude', 'knowledge', 'customer', 'interaction', 'done.Horrible', 'location', 'spend', 'almost', 'three', 'hours', 'end', 'leaving', 'piss', 'unsatisfied', 'clearly', 'different', 'price', 'manager', 'incapable', 'helping', 'rectify', 'situation', 'clueless', 'come', 'efficient', 'customer', 'service', 'whole', 'experience', 'make', 'cancel', 'T-Mobile', 'never', 'location', 'close', 'location', 'home.So', 'accord', 'website', 'minute', 'location', 'ask', 'need', 'something', 'devices', 'competitor', 'While', 'wait', 'store', 'customer', 'employee', 'standing', 'around', 'phone', 'another', 'sweeping', 'Multiple', 'times', 'try', 'someone', 'nothing', 'minute', 'greet', 'honestly', 'people', 'worthless', 'approach', 'customer', 'service', 'look', 'sleep', 'streets.Run', 'T-Mobile', 'consider', 'switching', 'whatever', 'carrier', 'matter', 'think', 'nightmare', 'experience', 'trust', 'staff', 'manager', 'especially', 'knowledgeable', 'employee', 'Dexter', 'Ronnie', 'working', 'carrier', 'phone', 'reception', 'spotty', 'location', 'Atlanta', 'except', 'T-Mobile', 'store', 'inside', 'store', 'without', 'drop', 'mystify', 'T-Mobile', 'stays', 'business.So', 'making', 'update', 'recent', 'month', 'month', 'phone', 'create', 'month', 'payment', 'prefer', 'surprise', 'discover', 'contract', 'would', 'today', 'figure', 'economical', 'decide', 'enlist', 'personal', 'formerly', 'phone', 'love', 'know', 'stuff', "don't.The", 'help', 'could', 'handle', 'everything', 'contract', 'ensure', 'going', 'mo-to-mo', 'remember', 'think', 'start', 'awesome', 'super-helpful', 'going', 'want', 'exactly', 'end', 'getting', 'Galaxy', 'first', 'touch', 'screen', 'definitely', 'adept', 'using', 'really', 'black', 'bright', 'initially', 'Retail', 'price', 'phone', 'opt', 'split', 'phone', 'definitely', 'bigger', 'crackberry', 'getting', 'things', 'receive.Slowly', 'surely', 'things', 'looking', 'location', 'still', 'ideal', 'set-up', 'experience', 'better', 'service', 'place', 'Regardless', 'stuff', 'here.Yeah', 'little', 'always', 'greet', 'crowd', 'employee', 'sometimes', 'inattentive', 'After', 'experience', 'issue', 'resolve', 'Sometimes', 'justify', 'means', 'prefer', 'rainbow', 'unicorn', 'guess', 'things', 'connected.I', 'T-Mobile', 'eleven', 'years', 'provide', 'service', 'periodically', 'better', 'pricing', '20/mo', 'phone', 'pricing', 'things', 'rolling', 'phone', 'service', 'T-Mobile', 'tell', '40/mo', 'phone', 'Incidentally', 'phone', 'another', 'carrier', 'T-Mobile', 'charge', 'entire', 'remain', 'month', 'month', 'T-Mobile', 'eMail', 'numbers', 'Un-Lock', 'phone', 'offer', 'signing', 'take', 'transition', 'costs', 'check', 'mobile', 'carrier', 'offering', 'regularly', 'phone', 'carrier', 'Price', 'every', 'month', 'ComCast', 'Inadequate', 'customer', 'service', 'ordering', 'stuff', 'internet', 'store', 'think', 'little', 'hard', 'customer', 'location.Back', 'August', 'rob', 'gunpoint', 'phone', 'phone', 'given', 'sympathy', 'suck', 'phone', 'cheap', 'right', 'lecture', 'insurance', 'would', 'Trying', 'insurance', 'cheap', 'phone', 'rob', 'Seriously', 'Today', 'upgrade', 'since', 'using', 'since', 'longer', 'acceptable', 'pass', 'upgrade', 'stand', 'minutes', 'without', 'hello', 'another', 'customer', 'second', 'woman', 'talking', 'phone', 'letting' ...
# ['Kudos', 'Tatiana', 'daughter', 'screen', 'cover', 'IPhone', 'treat', 'buying', '1,000', 'phone', 'Super', 'hospitable', 'Thanks', 'store', 'small', 'staff', 'service', 'slowHowever', 'help', 'staff', 'knowledgeable', 'experience', 'getting', 'need', 'issue', 'resolved.I', 'would', 'Davin.Great', 'customer', 'service', 'today', 'Cornell', 'right', 'juggle', 'several', 'customer', 'handle', 'customer', 'perfectly', 'phone', 'protect', 'Awesome', 'customer', 'service', 'T-Mobile', 'store', 'locate', 'inside', 'shopping', 'center', 'Target', 'corner', 'Austell', 'Connector', 'Google', 'Navigator', 'middle', 'shopping', 'center', 'Burgers.I', 'phone', 'want', 'activate', 'Pre-Pay', 'service', 'T-Mobile', 'Web-site', 'stick', 'mid-way', 'process', 'would', 'accept', 'anymore', 'try', 'horrendous', 'dealing', 'T-Mobile', 'Customer', 'Service', 'phone', 'Their', 'quality', 'suck', 'could', 'enough', 'thick', 'accent', 'Basically', 'store', 'fixed.Going', 'store', 'different', 'experience', 'help', 'white', 'moppy', 'remember', 'Anyway', 'friendly', 'helpful', 'everything', 'call', 'right', 'people', 'number', 'port', 'problem', 'everything', 'stuff', 'fix', 'pleased.This', 'sales', 'poorly', 'explain', 'promotion', 'purposely', 'getting', 'commission', 'check', 'stick', 'pay', 'beats', 'headphone', 'push', 'getting', 'supposedly', 'speak', 'manager', 'explain', 'promotion', 'actually', 'work', 'couldnt', 'anything', 'Props', 'fool', 'customer', 'check', 'return', 'again.I', 'store', 'upgrade', 'phone', 'causing', 'nonstop', 'issue', 'since', 'month', 'thinking', 'getting', 'galaxy', 'second', 'awful', 'think', 'would', 'issue', 'since', 'signing', 'would', 'demand', 'program', 'allow', 'upgrade', 'times', 'charge', 'entering', 'extremely', 'crowd', 'store', 'greet', 'manager', 'seem', 'explain', 'phone', 'problem', 'would', 'upgrade', 'pull', 'account', 'inform', 'whoever', 'activate', 'phone', 'simply', 'fail', 'demand', 'feature', 'account', 'though', 'family', 'feature', 'clearly', 'fault', 'would', 'feature', 't-mobile', 'employee', 'explain', 'fault', 'another', 'phone', 'bunch', 't-mobile', 'terms', 'understand', 'assume', 'terms', 'understandable', 'someone', 'know', 'nothing', 'tmobile', 'ask', 'explain', 'simply', 'repeating', 'thing', 'could', 'anything', 'immediatly', 'drove', 'store', 'Powder', 'Springs', 'Fitness', 'employee', 'happy', 'understand', 'situation', 'explain', 'everything', 'week', 'issue', 'resolve', 'store', 'Powders', 'Springs', 'Rd.My', 'check', 'could', 'replaceable', 'fixable', 'Unfortunately', 'two-year', 'contract', 'warranty', 'sales', 'people', 'look', 'thought', 'battery', 'defective', 'suggest', 'check', 'nearby', 'Batteries+Plus', 'replace', 'could', 'check', 'Target', 'Wal-Mart', 'would', 'cheap', 'purchase', 'could', 'try', 'selling', 'suggest', 'cheap', 'alternative', 'Thanks', 'store', 'experience', 'worth', 'drive', 'Exodo', 'Exodus', 'gentleman', 'assist', 'answer', 'question', 'getting', 'super', 'enthusiastic', 'person', 'walk', 'store', 'waiting', 'contact', 'transfer', 'wonder', 'employee', 'working', 'T-Mobile', 'Exodo', 'store', 'lying', 'price', 'discount', 'receive', 'lose', 'tmobile', 'customer', 'promotion', 'total', 'order', 'Considering', 'calling', 'buyer', 'beware.The', 'store', 'incredibly', 'times', 'longer', 'someone', 'courteous', 'helpful']
# ['call', 'ahead', 'holiday', 'weekend', 'question', 'try', 'decide', 'when/if', 'would', 'switch', 'carrier', 'simply', 'phone', 'Jasmine', 'help', 'impress', 'wait', 'store', 'commission', 'fault', 'rushing', 'lunch', 'break', 'minutes', 'Jasmine', 'aside', 'iPhone', 'great', 'advice', 'service', 'quality', 'saving', 'month', 'Walked', 'original', 'Samsung', 'trade', 'phone', 'still', 'iPhone', 'playing', 'manager', 'attempt', 'patient', 'interview', 'could', 'Jasmine', 'determine', 'square', 'start', 'finish', 'close', 'helpful', 'offering', 'phone', 'Bluetooth', 'park', 'close', 'enough', 'Thank', 'you.This', 'location', 'fantastic', 'customer', 'service', 'member', 'always', 'friendly', 'efficient', 'coming', 'years', 'always', 'pleasure', 'worst', 'customer', 'service', 'skill', 'husband', 'pulling', 'teeth', 'one-worded', 'answer', 'store.This', 'favorite', 'Mobile', 'location', 'customer', 'service', 'beyond', 'awesome', 'barrier', 'satisfy', 'happy', 'whatever', 'need', 'Michelle', 'store', 'manager', 'awesome', 'finding', 'solution', 'extremely', 'patient', 'Highly', 'recommend', 'Thank', 'location', 'worker', 'beyond', 'customer', 'take', 'Tmobile', 'employee', 'value', 'service', 'employee', 'always', 'sociable', 'compassionate', 'understanding', 'provide', 'service', 'customer', 'business']
# [['issue', 'phone', 'service', 'T-mobile', 'earliest', 'right', 'midtown', 'right', 'customer', 'service', 'knowledgeable', 'friendly', 'help', 'fix', 'issue', 'recommend', 'great', 'restaurant', 'meeting', 'topic', 'Thank', '5Church', 'great', 'suggestion', 'Thanks', 'upgrade', 'month', 'There', 'really', 'anyone', 'quiet', 'place', 'organize', 'associate', 'helpful', 'upgrade', 'process', 'Although', 'trouble', 'try', 'device', 'TeamMagenta', 'answer', 'question', 'going', 'upgrade', 'walk', 'upgrade', 'phone', 'ask', 'would', 'transfer', 'back', '10-15', 'minutes', 'helping', 'texting', 'helping', 'screw', 'transfer', 'times', 'ask', 'manager', 'either', 'store', 'hours', 'Terrible', 'service', 'extremely', 'unsatisfied', 'would', 'recommend', 'coming', 'location', 'better', 'service', 'hopefully', 'better', 'T-mobile', 'location', 'actually', 'know', 'doing.Maybe', 'lucky', 'young', 'name', "'Houston", 'super', 'friendly', 'hook', 'flash', 'friendly', 'accommodate', 'need', 'extremely', 'well.I', 'call', 'today', 'asking', 'certain', 'promotion', 'still', 'exist', 'customer', 'representative', 'end', 'yesterday', 'Really', 'would', 'courteous', 'ask', 'question', 'rude.I', 'awful', 'experience', 'different', 'location', 'locate', 'inside', 'Cumberland', 'things', 'already', 'second', 'remove', 'second', 'location', 'Tmobile', 'street', 'thought', 'insurance', 'month', 'later', 'found', 'never', 'Luckily', 'phone', 'still', 'warranty', 'close', 'shopping', 'different', 'carrier', 'loyal', 'T-mobile', 'customer', 'Jamin', 'Whitney', 'spend', 'almost', 'different', 'issue', 'correct', 'idiot', 'incompetent', 'former', 'employee', 'could', 'reach', 'manager', 'ask', 'recognize', '5-star', 'stellar', 'customer', 'service', 'performance', 'Short', 'version', 'inefficient', 'Avoid', 'unless', 'enjoy', 'waiting.Long', 'version', 'around', '11:40', 'phone', 'purchase', 'elsewhere', 'There', 'collection', 'individual', 'around', 'store', 'maybe', 'people', 'ahead', 'though', 'Around', 'minutes', 'later', "'next", "'line", 'clerk', 'point', 'decide', 'working', 'simultaneously', 'normally', 'applaud', 'multi-tasking', 'badly', 'rudely', 'really', 'bothered.Another', 'minutes', 'entirely', 'acquire', 'not.Finally', 'hand', 'done.The', 'experience', 'review', 'star', 'instead', '1.This', 'store', 'need', 'management', 'staff', 'Seems', 'T-Mobile', 'hire', 'uneducated', 'delinquent', 'streets..', 'knowledgeable', 'current', 'product', 'current', 'offer', 'location', 'place', 'suck', 'return', 'unless', 'major', 'change', 'made.Worst', 'T-mobile', 'Store', 'Horrible', 'service', 'attitude', 'Whether', 'people', 'right', 'bitter', 'angry', 'always', 'experience', 'second', 'chance', 'T-Mobile', 'pride', 'awesome', 'service', 'family', 'stick', 'decade', 'store', 'store', 'attitude', 'leaf', 'taste', 'mouth', 'never', 'enough', 'employee', 'handle', 'amount', 'customer', 'There', 'literally', 'associate', 'juggling', 'juggling', 'people', 'person', 'unable', 'multitask', 'could', 'literally', 'standing', 'queue', 'minutes', 'There', 'caveat', 'though', 'friend', 'certain', 'customer', 'everything', 'attend', 'Unless', 'President', 'Obama', 'First', 'Michelle', 'maybe', 'Oprah', 'attend', 'customer', 'order', 'appear', 'literally', 'three', 'people', 'Barack', 'Michelle', 'Oprah', 'attend', 'customer', 'order', 'arrival', 'mention', 'almost', 'ALWAYS', 'phone', 'hardly', 'new', 'phone', 'stock', 'center', 'literally', 'Peachtree', 'Street', 'phone', 'stock', 'cherry', 'PARKING', 'LIMITED', 'LIMITED', '*sigh*', 'Please', 'better', 'store', 'make', 'T-mobile', 'bad.Worst', 'tmobile', 'store', 'tmobile', 'customer', 'years', 'going', 'store', 'tempt', 'switch', 'carrier', 'specific', 'store', 'times', 'worst', 'customer', 'service', 'experience', 'texting', 'try', 'question', 'another', 'close', 'store', 'schedule', 'ignore', 'worker', 'friend', 'talking', 'weekend', 'assist', 'me.Yep', 'review', 'consistent', 'customer', 'service', 'visiting' ...

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 10
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=NUM_TOPICS)
for topic in topics:
    print(topic)
# Out:
# (0, '0.001*"T-Mobile" + 0.001*"service" + 0.001*"phone" + 0.001*"location" + 0.001*"customer" + 0.001*"experience" + 0.001*"store" + 0.001*"would" + 0.001*"month" + 0.001*"could"')
# (1, '0.028*"phone" + 0.024*"service" + 0.022*"customer" + 0.022*"T-Mobile" + 0.022*"store" + 0.015*"location" + 0.014*"would" + 0.011*"could" + 0.011*"experience" + 0.008*"month"')
# (2, '0.001*"store" + 0.001*"customer" + 0.001*"phone" + 0.001*"service" + 0.001*"would" + 0.001*"T-Mobile" + 0.001*"could" + 0.001*"manager" + 0.001*"explain" + 0.001*"employee"')
# (3, '0.001*"service" + 0.001*"phone" + 0.001*"customer" + 0.001*"store" + 0.001*"T-Mobile" + 0.001*"would" + 0.001*"could" + 0.001*"manager" + 0.001*"experience" + 0.001*"employee"')
# (4, '0.001*"store" + 0.001*"service" + 0.001*"customer" + 0.001*"T-Mobile" + 0.001*"phone" + 0.001*"location" + 0.001*"would" + 0.001*"employee" + 0.001*"could" + 0.001*"manager"')
# (5, '0.029*"phone" + 0.029*"store" + 0.024*"customer" + 0.016*"service" + 0.012*"would" + 0.011*"minutes" + 0.010*"employee" + 0.010*"could" + 0.008*"location" + 0.008*"T-Mobile"')
# (6, '0.029*"service" + 0.024*"customer" + 0.015*"phone" + 0.015*"location" + 0.015*"always" + 0.015*"Jasmine" + 0.010*"store" + 0.010*"manager" + 0.010*"employee" + 0.010*"beyond"')
# (7, '0.001*"service" + 0.001*"phone" + 0.001*"customer" + 0.001*"store" + 0.001*"T-Mobile" + 0.001*"location" + 0.001*"could" + 0.001*"would" + 0.001*"employee" + 0.001*"experience"')
# (8, '0.001*"phone" + 0.001*"store" + 0.001*"customer" + 0.001*"service" + 0.001*"T-Mobile" + 0.001*"could" + 0.001*"location" + 0.001*"would" + 0.001*"manager" + 0.001*"experience"')
# (9, '0.001*"store" + 0.001*"phone" + 0.001*"customer" + 0.001*"T-Mobile" + 0.001*"service" + 0.001*"location" + 0.001*"would" + 0.001*"could" + 0.001*"experience" + 0.001*"employee"')

# %%
import os
import nltk
from nltk import FreqDist
import pandas as pd
import matplotlib.pyplot as plt
import re
import requests
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_json('data.json')

# %%
df['name']
# Out:
# 0         t-mobile-atlanta-13
# 1          t-mobile-atlanta-3
# 2         t-mobile-atlanta-39
# 3            t-mobile-austell
# 4          t-mobile-lilburn-2
# 5         t-mobile-atlanta-30
# 6         t-mobile-atlanta-23
# 7         t-mobile-atlanta-46
# 8     t-mobile-lithia-springs
# 9          t-mobile-atlanta-7
# 10        t-mobile-east-point
# 11        t-mobile-atlanta-35
# 12        t-mobile-atlanta-28
# 13      t-mobile-alpharetta-7
# 14        t-mobile-atlanta-43
# Name: name, dtype: object

# %%
df.loc[df['name'] == 't-mobile-atlanta-30']['reviews'].array
# Out:
# <PandasArray>
# [[['I had a great experience switching from AT&T to T-Mobile and buying my 1st iPhone. Trey and Shamika were helpful, as well as fun. There was a glitch and we were unable to transfer contacts as well as photos to my new phone. Granted, my old phone was a Nokia Lumia & that was a challenge.', 4.0, '\n        2/7/2019\n    '], ['Wasted about an hour visiting this store that I won\'t get back. Staff seemed confused on how to address the problems I had, misleading me about certain things that I later found out on my own not to be the case after speaking with the call center. On top of that, the staff was rude as hell and it seemed like they just didn\'t want to be there. While at the store and speaking with a representative over the phone trying to assist the situation, I tried putting him in contact with the gentleman at the store assisting me, to which the gentleman immediately got defensive and said "I don\'t need to talk to them. I can call them on my own if I wanted to speak with them," as if I was challenging his authority or something. Who does that?!', 1.0, '\n        12/13/2017\n    '], ['I am so mad at them right now... They told us $40 per line but did not mention the minimum $120 if you get less than 4. What The Fools errand is wrong with (cell) phone companies?! They just keep hiding the truth and the facts. Really unhappy about them.', 1.0, '\n        7/23/2017\n            \n\n\n\n\n\nUpdated review\n\n'], ["Only been here once to get a prepaid phone. It's my First time in the US so I didn't know if my phone worked with the T-mobile network. The guys basically took a fresh new card and tested it, saying I don't have to pay if it doesn't work. That's definitely what I call going for the customer. =)", 5.0, '\n        8/2/2015\n    '], ["The store is good. \xa0The staff is helpful, the displays attractive, and the location very convenient for much of midtown. \xa0In that I'd agree with the other reviews.Two problems I would add to the discussion. \xa0One is staffing levels. \xa0Most times I've been in, there's a fairly long wait to talk to anyone, not necessarily because it's that crowded, but just because everything takes a really long time and there are only two people working.The second relates to how little T-Mobile allows its store staff to do. \xa0I'd asked for a new number, and the agent set it up without asking about area code preference. \xa0When he told me he'd set it up, I asked for one of a few area codes, but the system wouldn't let him make changes without a $15 fee. \xa0He could charge me the fee and ask me to fight T-Mobile over the phone for it later or just leave me with an area code no one's ever heard of. \xa0Two bad options, mostly thanks to how little T-Mobile lets them do.", 3.0, '\n        2/13/2015\n    '], ["Crazy to think that I've been a T-Mobile customer for over a decade. Since moving to Atlanta I've gone to a bunch of different T-Mobile locations -- pretty much any store that was closest to where I was at the time. After visiting the Tech Square location, I have finally found my store. The staff is always super knowledgeable, helpful and attentive. They actually listen to what you're saying and offer great insider advice on the best products and services for you. Finally found consistent and incredible customer service!Only downside...this location is quite small, but they have all the top phones. So it can get a it crowded on the weekends. (When the store is full, just wait in line and you'll get service faster than if you're browsing.) One thing I have to say is if you're there for something specific, like the hottest technology out there, you better snatch it up fast! Just visited last week to get a Samsung Galaxy S4 in the titanium color and they sold their last one a few hours earlier. It was the LAST titanium S4 in the Atlanta market!! Ended up just ordering one online though, so it worked out in the end.Overall great service and now I don't like going to any other stores!", 4.0,  ...
# Length: 1, dtype: object

# %%
subscription_key = 'c1005ffa18cc42ddbf916d2483bb2dd2'
assert subscription_key
text_analytics_base_url = "https://westcentralus.api.cognitive.microsoft.com/text/analytics/v2.0/"

# %%
def freq_words(x, terms = 30):
  all_words = ' '.join([text for text in x])
  all_words = all_words.split()
  
  fdist = FreqDist(all_words)
  words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})
  
  # selecting top 20 most frequent words
  d = words_df.nlargest(columns="count", n = terms) 
  plt.figure(figsize=(20,5))
  ax = sns.barplot(data=d, x= "word", y = "count")
  ax.set(ylabel = 'Count')
  plt.show()

# %%
len(df)
# Out:
# 15

# %%
for i in range(len(df)):
    print(i)
    idnum = 1
    docDic = []
    for rev in raw_revs:
        docDic.append({'id':idnum, 'language':'en', 'text': rev[0]})
        idnum += 1

    documents = {'documents' : docDic}
#     key_phrase_api_url = text_analytics_base_url + "keyPhrases"
#     headers   = {'Ocp-Apim-Subscription-Key': subscription_key}
#     response  = requests.post(key_phrase_api_url, headers=headers, json=documents)
#     key_phrases = response.json()
#     pprint(key_phrases)

    sentiment_api_url = text_analytics_base_url + "sentiment"
    response  = requests.post(sentiment_api_url, headers=headers, json=documents)
    sentiments = response.json()
    pprint(sentiments)

    #     entity_linking_api_url = text_analytics_base_url + "entities"
    #     response  = requests.post(entity_linking_api_url, headers=headers, json=documents)
    #     entities = response.json()
    #     pprint(entities)

    keyphr = []
    senti = []
    try:
        for j in range(len(key_phrases['documents'])):
            keyphr += key_phrases['documents'][j]['keyPhrases']
            senti += [sentiments['documents'][j]['score']]
    except:
        pprint(key_phrases)

    #     freq_words(keyphr)

    try:
        currStore = df.loc[i]['name']
    except:
        print(i)
    print("Store: " + currStore)
    print("Loc: " + str(i))
    raw_revs = df.loc[i]['reviews']
    scores = [rev[1] for rev in raw_revs]
    print ("Average Score: %f" % (sum(scores) / float(len(scores))))

    if (sum(senti) / float(len(senti)) > 0.5):
        print("HAPPY")
    else:
        print("BAD")
# Out:
# 0
# {'documents': [{'id': '1',
#                 'keyPhrases': ['issues',
#                                'right',
#                                'great restaurants',
#                                'great suggestion',
#                                'customer service reps',
#                                'Church',
#                                'work',
#                                'meeting',
#                                'phone',
#                                'topic',
#                                'T-mobile',
#                                'midtown',
#                                'Thanks']},
#                {'id': '2',
#                 'keyPhrases': ['upgrade process',
#                                'associates',
#                                'TeamMagenta',
#                                'new device',
#                                'place',
#                                'trouble',
#                                'questions',
#                                'months',
#                                'upgrades']},
#                {'id': '3',
#                 'keyPhrases': ['better service',
#                                'transfer',
#                                'better T-mobile location',
#                                'Terrible service',
#                                'store',
#                                'times',
#                                'hours',
#                                'manager',
#                                'data',
#                                'phone',
#                                'minutes',
#                                'girl']},
#                {'id': '4',
#                 'keyPhrases': ['Houston',
#                                'rep',
#                                'young man',
#                                'needs',
#                                'flash']},
#                {'id': '5',
#                 'keyPhrases': ['customer representative',
#                                'line',
#                                'certain promotion',
#                                'questions',
#                                'fact']},
#                {'id': '6',
#                 'keyPhrases': ['different carrier',
#                                'different locations',
#                                'different issues',
#                                'loyal T-mobile customer',
#                                'star stellar customer service performance',
#                                'yrs',
#                                'street',
#                                'guy',
#                                'awful experiences',
#                                'shopping',
#                                'idiot',
#                                'employee',
#                                'Cumberland mall',
#                                'things',
#                                'Tmobile',
#                                'insurance',
#                                'Jamin',
#                                'Whitney',
#                                'hour',
#                                'phone',
#                                'warranty',
#                                'months',
#                                'managers',
#                                'line']},
#                {'id': '7',
#                 'keyPhrases': ['new sim card',
#                                'line',
#                                'minutes',
#                                'Short version',
#                                'Long version',
#                                'store',
#                                'sort of multi-tasking',
#                                'collection of individuals',
#                                'wait',
#                                'phone',
#                                'clerk',
#                                'point',
#                                'review',
#                                'stars',
#                                'people',
#                                'lady']},
#                {'id': '8',
#                 'keyPhrases': ['current products',
#                                'current offers',
#                                'uneducated delinquents',
#                                'store',
#                                'new management',
#                                'staff',
#                                'good location',
#                                'place sucks',
#                                'T-Mobile',
#                                'streets']},
#                {'id': '9',
#                 'keyPhrases': ['Store',
#                                'bad attitudes',
#                                'bad taste',
#                                'bad experiences',
#                                'people',
#                                'attend',
#                                'T-mobile look bad',
#                                'certain customers',
#                                'Oprah',
#                                'stock',
#                                'newer phones',
#                                'year',
#                                'main new phones',
#                                'awesome service',
#                                'Lady Michelle',
#                                'Horrible service',
#                                'order of arrival',
#                                'associate juggling',
#                                'city center',
#                                'Peachtree Street',
#                                'T-Mobile prides',
#                                'President Obama',
#                                'PARKING',
#                                'Barack',
#                                'chance',
#                                'FAIL',
#                                'family',
#                                'friends',
#                                'mouth',
#                                'ish cray',
#                                'person',
#                                'queue',
#                                'minutes',
#                                'guys',
#                                'cherry',
#                                'employees',
#                                'sigh',
#                                'Worst',
#                                'decade',
#                                'caveat']},
#                {'id': '10',
#                 'keyPhrases': ['Worst tmobile store',
#                                'specific store',
#                                'tmobile customer',
#                                'worst customer service',
#                                'times',
#                                'years',
#                                'workers friend',
#                                'questions',
#                                'life',
#                                'carriers',
#                                'girl',
#                                'weekend']},
#                {'id': '11',
#                 'keyPhrases': ['aforementioned customer',
#                                'Poor customer service',
#                                'phone charger',
#                                'store details',
#                                'wait',
#                                'voicemail',
#                                'couple of minutes',
#                                'time',
#                                'town',
#                                'line',
#                                'employees',
#                                'guy',
#                                'reviews',
#                                'day',
#                                'situation',
#                                'problem',
#                                'T-Mobile',
#                                'recording']},
#                {'id': '12',
#                 'keyPhrases': ['store exchange',
#                                'T-Mobile store',
#                                'store warranty exchange',
#                                'phone',
#                                'Buckhead store',
#                                'exchange process',
#                                'stock',
#                                'warranty period',
#                                'Option B',
#                                'account',
#                                'great way',
#                                'associate',
#                                'deal',
#                                'touch screen',
#                                'Midtown',
#                                'time',
#                                'right location',
#                                'lot',
#                                'Yelp365',
#                                'keyboard',
#                                'person',
#                                'remedies',
#                                'stores',
#                                'minutes']},
#                {'id': '13',
#                 'keyPhrases': ['super awesome phone',
#                                'new phone',
#                                'customer service',
#                                'AWESOME SERVICE',
#                                'system',
#                                'loyal T Mobile customer',
#                                'store',
#                                'multiple times',
#                                'years',
#                                'trouble',
#                                'husband',
#                                'bag',
#                                'horrible reception',
#                                'phones',
#                                'weeks',
#                                'free upgrade',
#                                'mail',
#                                'refund',
#                                'account',
#                                'robbery',
#                                'lowest price',
#                                'ups',
#                                'care',
#                                'Darrell',
#                                'guys',
#                                'gunpoint',
#                                'function',
#                                'advantage',
#                                'complications']},
#                {'id': '14',
#                 'keyPhrases': ['cell phone customers',
#                                'hazel contact lenses',
#                                'young black girl',
#                                'curly hair weave',
#                                'control',
#                                'terminal breast cancer',
#                                'college degree',
#                                'store',
#                                'goodbye',
#                                'stage',
#                                'manager',
#                                'nice day',
#                                'worst attitude',
#                                'service',
#                                'GTFOH',
#                                'condiscending manner',
#                                'folks',
#                                'Corporate',
#                                'star',
#                                'sentence',
#                                'year',
#                                'nerve',
#                                'Complaint']},
#                {'id': '15',
#                 'keyPhrases': ['reason',
#                                'T-Mobile store',
#                                'stars',
#                                'new Android',
#                                'new handset',
#                                'G1 phone',
#                                'business phone-wise',
#                                'minutes of productive time',
#                                'good service',
#                                'person',
#                                'way',
#                                'rainstorm',
#                                'telephone support',
#                                'Motorola Cliq',
#                                'individual salespeople',
#                                'A-OK',
#                                'hour',
#                                'selection of phones',
#                                'visit',
#                                'keyboard model',
#                                'mid-afternoon crowd',
#                                'water',
#                                'rating',
#                                'door',
#                                'week',
#                                'staffpeople',
#                                'saleswoman',
#                                'fluke']},
#                {'id': '16',
#                 'keyPhrases': ['store',
#                                'refund',
#                                'assistant manager',
#                                'restocking fee',
#                                'customer service',
#                                'phone home',
#                                'new service',
#                                'situation',
#                                'worst cell phone provider',
#                                'Worst experience',
#                                'customer device',
#                                'associate',
#                                't mobile',
#                                'employee',
#                                'days',
#                                'row',
#                                'computer',
#                                'house',
#                                'chant']},
#                {'id': '17',
#                 'keyPhrases': ['things',
#                                'money',
#                                'new iPhone',
#                                'bad attitude',
#                                'pockets',
#                                'hand',
#                                'lady']},
#                {'id': '18',
#                 'keyPhrases': ['cell phone plan',
#                                'T Mobile customer',
#                                'help',
#                                'switch',
#                                'different location',
#                                'original plan',
#                                'customer service guy',
#                                'yrs',
#                                'month',
#                                'Sidekick',
#                                'number',
#                                'money',
#                                'slowy deterorating',
#                                'chick',
#                                'disappointed review',
#                                'sales rep',
#                                'minutes',
#                                'lot',
#                                'advice',
#                                'internet']}],
#  'errors': []}
# {'documents': [{'id': '1', 'score': 0.9026597738265991},
#                {'id': '2', 'score': 0.22562018036842346},
#                {'id': '3', 'score': 0.09106448292732239},
#                {'id': '4', 'score': 0.9685330390930176},
#                {'id': '5', 'score': 0.1319631040096283},
#                {'id': '6', 'score': 0.8289533257484436},
#                {'id': '7', 'score': 0.08572414517402649},
#                {'id': '8', 'score': 0.09125787019729614},
#                {'id': '9', 'score': 0.011922210454940796},
#                {'id': '10', 'score': 0.08076667785644531},
#                {'id': '11', 'score': 0.20382162928581238},
#                {'id': '12', 'score': 0.24971884489059448},
#                {'id': '13', 'score': 0.7823215126991272},
#                {'id': '14', 'score': 0.08945304155349731},
#                {'id': '15', 'score': 0.7833021879196167},
#                {'id': '16', 'score': 0.011663615703582764},
#                {'id': '17', 'score': 0.09922415018081665},
#                {'id': '18', 'score': 0.17370757460594177}],
#  'errors': []}
# Store: t-mobile-atlanta-13
# Loc: 0
# Average Score: 2.444444
# BAD
# 1
# {'documents': [{'id': '1',
#                 'keyPhrases': ['issues',
#                                'right',
#                                'great restaurants',
#                                'great suggestion',
#                                'customer service reps',
#                                'Church',
#                                'work',
#                                'meeting',
#                                'phone',
#                                'topic',
#                                'T-mobile',
#                                'midtown',
#                                'Thanks']},
#                {'id': '2',
#                 'keyPhrases': ['upgrade process',
#                                'associates',
#                                'TeamMagenta',
#                                'new device',
#                                'place',
#                                'trouble',
#                                'questions',
#                                'months',
#                                'upgrades']},
#                {'id': '3',
#                 'keyPhrases': ['better service',
#                                'transfer',
#                                'better T-mobile location',
#                                'Terrible service',
#                                'store',
#                                'times',
#                                'hours',
#                                'manager',
#                                'data',
#                                'phone',
#                                'minutes',
#                                'girl']},
#                {'id': '4',
#                 'keyPhrases': ['Houston',
#                                'rep',
#                                'young man',
#                                'needs',
#                                'flash']},
#                {'id': '5',
#                 'keyPhrases': ['customer representative',
#                                'line',
#                                'certain promotion',
#                                'questions',
#                                'fact']},
#                {'id': '6',
#                 'keyPhrases': ['different carrier',
#                                'different locations',
#                                'different issues',
#                                'loyal T-mobile customer',
#                                'star stellar customer service performance',
#                                'yrs',
#                                'street',
#                                'guy',
#                                'awful experiences',
#                                'shopping',
#                                'idiot',
#                                'employee',
#                                'Cumberland mall',
#                                'things',
#                                'Tmobile',
#                                'insurance',
#                                'Jamin',
#                                'Whitney',
#                                'hour',
#                                'phone',
#                                'warranty',
#                                'months',
#                                'managers',
#                                'line']},
#                {'id': '7',
#                 'keyPhrases': ['new sim card',
#                                'line',
#                                'minutes',
#                                'Short version',
#                                'Long version',
#                                'store',
#                                'sort of multi-tasking',
#                                'collection of individuals',
#                                'wait',
#                                'phone',
#                                'clerk',
#                                'point',
#                                'review',
#                                'stars',
#                                'people',
#                                'lady']},
#                {'id': '8',
#                 'keyPhrases': ['current products',
#                                'current offers',
#                                'uneducated delinquents',
#                                'store',
#                                'new management',
#                                'staff',
#                                'good location',
#                                'place sucks',
#                                'T-Mobile',
#                                'streets']},
#                {'id': '9',
#                 'keyPhrases': ['Store',
#                                'bad attitudes',
#                                'bad taste',
#                                'bad experiences',
#                                'people',
#                                'attend',
#                                'T-mobile look bad',
#                                'certain customers',
#                                'Oprah',
#                                'stock',
#                                'newer phones',
#                                'year',
#                                'main new phones',
#                                'awesome service',
#                                'Lady Michelle',
#                                'Horrible service',
#                                'order of arrival',
#                                'associate juggling',
#                                'city center',
#                                'Peachtree Street',
#                                'T-Mobile prides',
#                                'President Obama',
#                                'PARKING',
#                                'Barack',
#                                'chance',
#                                'FAIL',
#                                'family',
#                                'friends',
#                                'mouth',
#                                'ish cray',
#                                'person',
#                                'queue',
#                                'minutes',
#                                'guys',
#                                'cherry',
#                                'employees',
#                                'sigh',
#                                'Worst',
#                                'decade',
#                                'caveat']},
#                {'id': '10',
#                 'keyPhrases': ['Worst tmobile store',
#                                'specific store',
#                                'tmobile customer',
#                                'worst customer service',
#                                'times',
#                                'years',
#                                'workers friend',
#                                'questions',
#                                'life',
#                                'carriers',
#                                'girl',
#                                'weekend']},
#                {'id': '11',
#                 'keyPhrases': ['aforementioned customer',
#                                'Poor customer service',
#                                'phone charger',
#                                'store details',
#                                'wait',
#                                'voicemail',
#                                'couple of minutes',
#                                'time',
#                                'town',
#                                'line',
#                                'employees',
#                                'guy',
#                                'reviews',
#                                'day',
#                                'situation',
#                                'problem',
#                                'T-Mobile',
#                                'recording']},
#                {'id': '12',
#                 'keyPhrases': ['store exchange',
#                                'T-Mobile store',
#                                'store warranty exchange',
#                                'phone',
#                                'Buckhead store',
#                                'exchange process',
#                                'stock',
#                                'warranty period',
#                                'Option B',
#                                'account',
#                                'great way',
#                                'associate',
#                                'deal',
#                                'touch screen',
#                                'Midtown',
#                                'time',
#                                'right location',
#                                'lot',
#                                'Yelp365',
#                                'keyboard',
#                                'person',
#                                'remedies',
#                                'stores',
#                                'minutes']},
#                {'id': '13',
#                 'keyPhrases': ['super awesome phone',
#                                'new phone',
#                                'customer service',
#                                'AWESOME SERVICE',
#                                'system',
#                                'loyal T Mobile customer',
#                                'store',
#                                'multiple times',
#                                'years',
#                                'trouble',
#                                'husband',
#                                'bag',
#                                'horrible reception',
#                                'phones',
#                                'weeks',
#                                'free upgrade',
#                                'mail',
#                                'refund',
#                                'account',
#                                'robbery',
#                                'lowest price',
#                                'ups',
#                                'care',
#                                'Darrell',
#                                'guys',
#                                'gunpoint',
#                                'function',
#                                'advantage',
#                                'complications']},
#                {'id': '14',
#                 'keyPhrases': ['cell phone customers',
#                                'hazel contact lenses',
#                                'young black girl',
#                                'curly hair weave',
#                                'control',
#                                'terminal breast cancer',
#                                'college degree',
#                                'store',
#                                'goodbye',
#                                'stage',
#                                'manager',
#                                'nice day',
#                                'worst attitude',
#                                'service',
#                                'GTFOH',
#                                'condiscending manner',
#                                'folks',
#                                'Corporate',
#                                'star',
#                                'sentence',
#                                'year',
#                                'nerve',
#                                'Complaint']},
#                {'id': '15',
#                 'keyPhrases': ['reason',
#                                'T-Mobile store',
#                                'stars',
#                                'new Android',
#                                'new handset',
#                                'G1 phone',
#                                'business phone-wise',
#                                'minutes of productive time',
#                                'good service',
#                                'person',
#                                'way',
#                                'rainstorm',
#                                'telephone support',
#                                'Motorola Cliq',
#                                'individual salespeople',
#                                'A-OK',
#                                'hour',
#                                'selection of phones',
#                                'visit',
#                                'keyboard model',
#                                'mid-afternoon crowd',
#                                'water',
#                                'rating',
#                                'door',
#                                'week',
#                                'staffpeople',
#                                'saleswoman',
#                                'fluke']},
#                {'id': '16',
#                 'keyPhrases': ['store',
#                                'refund',
#                                'assistant manager',
#                                'restocking fee',
#                                'customer service',
#                                'phone home',
#                                'new service',
#                                'situation',
#                                'worst cell phone provider',
#                                'Worst experience',
#                                'customer device',
#                                'associate',
#                                't mobile',
#                                'employee',
#                                'days',
#                                'row',
#                                'computer',
#                                'house',
#                                'chant']},
#                {'id': '17',
#                 'keyPhrases': ['things',
#                                'money',
#                                'new iPhone',
#                                'bad attitude',
#                                'pockets',
#                                'hand',
#                                'lady']},
#                {'id': '18',
#                 'keyPhrases': ['cell phone plan',
#                                'T Mobile customer',
#                                'help',
#                                'switch',
#                                'different location',
#                                'original plan',
#                                'customer service guy',
#                                'yrs',
#                                'month',
#                                'Sidekick',
#                                'number',
#                                'money',
#                                'slowy deterorating',
#                                'chick',
#                                'disappointed review',
#                                'sales rep',
#                                'minutes',
#                                'lot',
#                                'advice',
#                                'internet']}],
#  'errors': []}
# {'documents': [{'id': '1', 'score': 0.9026597738265991},
#                {'id': '2', 'score': 0.22562018036842346},
#                {'id': '3', 'score': 0.09106448292732239},
#                {'id': '4', 'score': 0.9685330390930176},
#                {'id': '5', 'score': 0.1319631040096283},
#                {'id': '6', 'score': 0.8289533257484436},
#                {'id': '7', 'score': 0.08572414517402649},
#                {'id': '8', 'score': 0.09125787019729614},
#                {'id': '9', 'score': 0.011922210454940796},
#                {'id': '10', 'score': 0.08076667785644531},
#                {'id': '11', 'score': 0.20382162928581238},
#                {'id': '12', 'score': 0.24971884489059448},
#                {'id': '13', 'score': 0.7823215126991272},
#                {'id': '14', 'score': 0.08945304155349731},
#                {'id': '15', 'score': 0.7833021879196167},
#                {'id': '16', 'score': 0.011663615703582764},
#                {'id': '17', 'score': 0.09922415018081665},
#                {'id': '18', 'score': 0.17370757460594177}],
#  'errors': []}
# Store: t-mobile-atlanta-3
# Loc: 1
# Average Score: 2.500000
# BAD
# 2
# {'documents': [{'id': '1',
#                 'keyPhrases': ['customer service',
#                                'charts',
#                                'great experience',
#                                'staff']},
#                {'id': '2',
#                 'keyPhrases': ['Complaint',
#                                'times',
#                                'thing',
#                                'workers',
#                                'hour',
#                                'mins',
#                                'store']},
#                {'id': '3',
#                 'keyPhrases': ['location',
#                                'T-Mobile customer',
#                                'customer service',
#                                'store manager TJ',
#                                'way customer interaction',
#                                'experienced service',
#                                'light',
#                                'face-to-face team members',
#                                'quality',
#                                'professional attitude',
#                                'current offers',
#                                'stories',
#                                'knowledge',
#                                'Samsung',
#                                'Thomas',
#                                'tight ship',
#                                'product',
#                                'tablet',
#                                'stock',
#                                'years',
#                                'best',
#                                'devices',
#                                'time',
#                                'guys']},
#                {'id': '4',
#                 'keyPhrases': ['closest location',
#                                'Horrible location',
#                                'efficient customer service',
#                                'different prices',
#                                'line',
#                                'home',
#                                'experience',
#                                'T-Mobile',
#                                'manager',
#                                'situation',
#                                'hours',
#                                'rep']},
#                {'id': '5',
#                 'keyPhrases': ['minute wait',
#                                'customer service',
#                                'approach',
#                                'location',
#                                'devices',
#                                'competitor',
#                                'Multiple times',
#                                'job',
#                                'people',
#                                'store',
#                                'employees',
#                                'website',
#                                'phone',
#                                'streets']},
#                {'id': '6',
#                 'keyPhrases': ['T-Mobile store',
#                                'lame carrier',
#                                'best',
#                                'knowledgeable employees Dexter',
#                                'locations',
#                                'cell phone reception',
#                                'Ronnie',
#                                'Atlanta area',
#                                'staff',
#                                'managers',
#                                'matter',
#                                'bars',
#                                'business',
#                                'nightmare',
#                                'idea']},
#                {'id': '7',
#                 'keyPhrases': ['new phone',
#                                'T-Mo',
#                                'help',
#                                'new toy',
#                                'month payment plan',
#                                'year contract',
#                                'recent news - T',
#                                'guru',
#                                'Adam R',
#                                'Retail price',
#                                'bright pink case',
#                                'Yelp',
#                                'things',
#                                'crackberry',
#                                'updates',
#                                'Galaxy s4',
#                                'touch screen',
#                                'stuff',
#                                'guy',
#                                'idea',
#                                'boys']},
#                {'id': '8',
#                 'keyPhrases': ['things',
#                                'better service',
#                                'ideal set-up',
#                                'places',
#                                'employees',
#                                'experience',
#                                'issue',
#                                'end',
#                                'means',
#                                'rainbows',
#                                'unicorns',
#                                'location',
#                                'stuff']},
#                {'id': '9',
#                 'keyPhrases': ['T-Mobile',
#                                'cell phone carrier',
#                                'phone service',
#                                'cell phones',
#                                'best pricing',
#                                'mo plan',
#                                'Best Price',
#                                'good service',
#                                'better pricing',
#                                'entire remaining month',
#                                'years',
#                                'Lock',
#                                'bite',
#                                'transition costs',
#                                'months',
#                                'things',
#                                'mobile carriers',
#                                'numbers',
#                                'end',
#                                'ComCast']},
#                {'id': '10',
#                 'keyPhrases': ['new phone',
#                                'cheap phone',
#                                'insurance',
#                                'Inadequate customer service',
#                                'year upgrade mark',
#                                'customers',
#                                'models',
#                                'toddler play',
#                                'day',
#                                'stuff',
#                                'stores',
#                                'Gee',
#                                'internet',
#                                'alarm system',
#                                'location',
#                                'sympathy',
#                                'employees',
#                                'eyelash',
#                                'ease',
#                                'city',
#                                'sucks',
#                                "i've",
#                                'gunpoint',
#                                'bag',
#                                'woman',
#                                'help',
#                                'minutes',
#                                'beeping',
#                                'business']},
#                {'id': '11',
#                 'keyPhrases': ['customer service line',
#                                'Store associates',
#                                'T-Mobile associates',
#                                'top-notch customer service',
#                                'T-Mobile location',
#                                'Lee rocks',
#                                'store manager',
#                                'quality of service',
#                                'best customer',
#                                'time',
#                                'Jamie',
#                                'proper good service',
#                                'busy location',
#                                'hours',
#                                'type of attention',
#                                'type of satisfaction',
#                                'Nikisha Holt',
#                                'phone',
#                                'team',
#                                'incoming customers',
#                                'attitude',
#                                'sales rep',
#                                'years',
#                                'help',
#                                'complaint',
#                                'issue',
#                                'world',
#                                'locations',
#                                'minutes',
#                                'waiver']},
#                {'id': '12',
#                 'keyPhrases': ['location',
#                                'phone trade',
#                                'credit check',
#                                'temporary phone number',
#                                'permission',
#                                'ETF',
#                                'lunch break',
#                                'account',
#                                'people',
#                                'sales',
#                                'current carrier',
#                                'promotion',
#                                'ATT',
#                                'guy']},
#                {'id': '13',
#                 'keyPhrases': ['rural area',
#                                'Buckhead area of Atlanta',
#                                'poor service',
#                                'contract cancellation fee',
#                                'time',
#                                'new service request',
#                                'T-Mobile retail locations',
#                                't-mobile phone',
#                                'situation',
#                                'experience',
#                                'remedy',
#                                'Kirkwood community of Atlanta',
#                                'particular store',
#                                'particular circumstance',
#                                'little trouble',
#                                'new department',
#                                'trouble ticket',
#                                'couple of days',
#                                'previous location',
#                                'exception',
#                                'shoppers',
#                                'idea',
#                                'home',
#                                'fleeting',
#                                'G instances',
#                                'minutes',
#                                'data',
#                                'early term',
#                                'engineers',
#                                'year',
#                                'solid ability',
#                                'mile',
#                                'Decatur square',
#                                'insight',
#                                'explanation',
#                                'length',
#                                'technician',
#                                'hopes',
#                                'choice',
#                                'nickel',
#                                'words',
#                                'planned upgrades',
#                                'months',
#                                'results',
#                                'repair',
#                                'company',
#                                'things',
#                                'future customers',
#                                'story',
#                                'notes',
#                                'week',
#                                'signal',
#                                'issue',
#                                'step',
#                                'cancellations',
#                                'review',
#                                'house',
#                                'mind',
#                                'terminations',
#                                'options',
#                                'deal',
#                                'content']},
#                {'id': '14',
#                 'keyPhrases': ['scheduled appointment',
#                                'service technician',
#                                'Terrible customer service',
#                                'presence',
#                                'hour',
#                                'total counters',
#                                'Buckhead',
#                                'customers',
#                                'lunch',
#                                'employees']}],
#  'errors': []}
# {'documents': [{'id': '1', 'score': 0.8873186111450195},
#                {'id': '2', 'score': 0.06980264186859131},
#                {'id': '3', 'score': 0.9469496011734009},
#                {'id': '4', 'score': 0.02580079436302185},
#                {'id': '5', 'score': 0.5},
#                {'id': '6', 'score': 0.07002350687980652},
#                {'id': '7', 'score': 0.9234090447425842},
#                {'id': '8', 'score': 0.1332056224346161},
#                {'id': '9', 'score': 0.5},
#                {'id': '10', 'score': 0.12860533595085144},
#                {'id': '11', 'score': 0.829011857509613},
#                {'id': '12', 'score': 0.5},
#                {'id': '13', 'score': 0.15505504608154297},
#                {'id': '14', 'score': 0.03512030839920044}],
#  'errors': []}
# Store: t-mobile-atlanta-39
# Loc: 2
# Average Score: 2.100000
# BAD
# 3
# {'documents': [{'id': '1',
#                 'keyPhrases': ['remodeled store',
#                                'wonderful new staff',
#                                'year']},
#                {'id': '2',
#                 'keyPhrases': ['bad review',
#                                'chance',
#                                'Horrible service',
#                                'rating']},
#                {'id': '3',
#                 'keyPhrases': ['ratchett weave',
#                                'Kiara Ashanti Dobbs',
#                                'Falcons',
#                                'type of customer service',
#                                'mess',
#                                'wrong profession']},
#                {'id': '4',
#                 'keyPhrases': ['new phone',
#                                'credit',
#                                'new Samsung Note',
#                                'day',
#                                'bits of sandwich',
#                                'colorless phones',
#                                'Samsung Galaxy',
#                                'dark color',
#                                'lunch hour',
#                                'roast beef sandwich',
#                                'Google',
#                                'little sister',
#                                'contact information',
#                                'envious of iPhone owners',
#                                'laggy performance',
#                                'account sync',
#                                'months',
#                                'decade',
#                                'real life',
#                                'Hammond Drive',
#                                'conversation',
#                                'HTC Sensation',
#                                'hand',
#                                'geniuses',
#                                'cerebral signals',
#                                'teeth',
#                                'mouth',
#                                "Arby's",
#                                'visit',
#                                'place',
#                                'bunch of things',
#                                'smartphone',
#                                'loyal customer',
#                                'smooth transition',
#                                'questions',
#                                'term usage',
#                                'text messages',
#                                'photos',
#                                'moo-lah',
#                                'bad boy',
#                                'hesitation',
#                                'service',
#                                'T-Mobile',
#                                'kind lady',
#                                'calendar',
#                                'meantime',
#                                'afternoon',
#                                'good luck',
#                                'vein',
#                                'store',
#                                'unpleasant experience',
#                                'mini-mirror',
# ...
#                                'windows',
#                                'Lenox Mall',
#                                'manual',
#                                'Way',
#                                'guys',
#                                'Apple',
#                                'patient',
#                                'market',
#                                'retail representative',
#                                'week',
#                                'case',
#                                'minutes',
#                                'features',
#                                'unit']},
#                {'id': '6', 'keyPhrases': ['easy kioskand', 'staff']}],
#  'errors': []}
# {'documents': [{'id': '1', 'score': 0.21105289459228516},
#                {'id': '2', 'score': 0.10165596008300781},
#                {'id': '3', 'score': 0.06924286484718323},
#                {'id': '4', 'score': 0.20378583669662476},
#                {'id': '5', 'score': 0.7578037977218628},
#                {'id': '6', 'score': 0.9893800020217896}],
#  'errors': []}
# Store: t-mobile-east-point
# Loc: 10
# Average Score: 1.833333
# BAD
# 11
# {'documents': [{'id': '1',
#                 'keyPhrases': ['horrible customer service',
#                                'true customer service',
#                                'Verizon store',
#                                'wait time',
#                                'manager',
#                                'minutes',
#                                'help',
#                                'Crystal']},
#                {'id': '2',
#                 'keyPhrases': ['additional fees',
#                                'Miss Lulu',
#                                'point',
#                                'paperwork',
#                                'activation fee',
#                                'fine print',
#                                'shame']},
#                {'id': '3',
#                 'keyPhrases': ['customer service rep',
#                                'TMOBILE',
#                                'store',
#                                'Edward',
#                                'rebate',
#                                'Velma',
#                                'mins',
#                                'supervisor',
#                                'Samsung promotion',
#                                'couple of phones',
#                                'Sprint',
#                                'family',
#                                'coverage',
#                                'Social Media sites',
#                                'money',
#                                'switch',
#                                'bait',
#                                'plan',
#                                'lines',
#                                'problem',
#                                'misinformation',
#                                'customers',
#                                'soldier',
#                                'hold',
#                                'Saul',
#                                'Robinson',
#                                'avail',
#                                'treatment']},
#                {'id': '4',
#                 'keyPhrases': ['new leaf',
#                                'new year',
#                                'new phone',
#                                'Tmobile locations',
#                                'good day',
#                                'wait',
#                                'people',
#                                'problem',
#                                'associate']},
#                {'id': '5',
#                 'keyPhrases': ['phone bill',
#                                'new phone service',
#                                'Bunch of high school dropouts',
#                                'Worst t-mobile store',
#                                'long wait time',
#                                'employees',
#                                'sales',
#                                'months',
#                                'transaction',
#                                'clue']},
#                {'id': '6',
#                 'keyPhrases': ['store',
#                                'busy texting',
#                                'big time',
#                                'super busy - long waiting lines',
#                                'past visits',
#                                'samsung galaxy s3',
#                                'preinstalled jelly bean',
#                                'Overall experience',
#                                'box',
#                                'questions',
#                                'customer service',
#                                'phone',
#                                'guys',
#                                'nerves',
#                                'end']}],
#  'errors': []}
# {'documents': [{'id': '1', 'score': 0.24651074409484863},
#                {'id': '2', 'score': 0.20088505744934082},
#                {'id': '3', 'score': 0.5},
#                {'id': '4', 'score': 0.2506968080997467},
#                {'id': '5', 'score': 0.5},
#                {'id': '6', 'score': 0.11016720533370972}],
#  'errors': []}
# Store: t-mobile-atlanta-35
# Loc: 11
# Average Score: 4.000000
# BAD
# 12
# {'documents': [{'id': '1',
#                 'keyPhrases': ['new phone',
#                                'new iPhone',
#                                'flip phone',
#                                'Jasmine set',
#                                'cool iPhone',
#                                'work day',
#                                'quality',
#                                'great advice',
#                                'service',
#                                'original Samsung S4',
#                                'store',
#                                'Bluetooth',
#                                'patient',
#                                'Good job guys',
#                                'bill',
#                                'carriers',
#                                'holiday weekend',
#                                'lunch break',
#                                'sale',
#                                'Kyle',
#                                'time',
#                                'manager',
#                                'interview',
#                                'month',
#                                'commission',
#                                'questions',
#                                'fault',
#                                'minutes',
#                                'face',
#                                'finish']},
#                {'id': '2',
#                 'keyPhrases': ['location',
#                                'fantastic customer service',
#                                'team members',
#                                'years',
#                                'pleasure']},
#                {'id': '3',
#                 'keyPhrases': ['Abel',
#                                'worst customer service skills',
#                                'teeth',
#                                'worded answers',
#                                'husband',
#                                'store']},
#                {'id': '4',
#                 'keyPhrases': ['store manager',
#                                'favorite T Mobile location',
#                                'solution',
#                                'Michelle',
#                                'customer service',
#                                'barrier']},
#                {'id': '5',
#                 'keyPhrases': ['employees',
#                                'service',
#                                'customers',
#                                'care',
#                                'location',
#                                'workers',
#                                'Tmobile',
#                                'business']}],
#  'errors': []}
# {'documents': [{'id': '1', 'score': 0.8087184429168701},
#                {'id': '2', 'score': 0.940973162651062},
#                {'id': '3', 'score': 0.016941547393798828},
#                {'id': '4', 'score': 0.9879929423332214},
#                {'id': '5', 'score': 0.8830830454826355}],
#  'errors': []}
# Store: t-mobile-atlanta-28
# Loc: 12
# Average Score: 2.600000
# HAPPY
# 13
# {'documents': [{'id': '1',
#                 'keyPhrases': ['smile',
#                                'door',
#                                'sales associates',
#                                'excellent customer service',
#                                'single sales associate',
#                                'great attitude',
#                                'Kroger',
#                                'Town Center mall',
#                                'Kennesaw',
#                                'case',
#                                'screen protector',
#                                'South Cobb',
#                                'T-Mobile stores',
#                                'horrible experiences',
#                                'location',
#                                'Cumberland',
#                                'care',
#                                'time',
#                                'phone']},
#                {'id': '2',
#                 'keyPhrases': ['monthly bill',
#                                'Cumberland mall',
#                                't mobile',
#                                'headquarters',
#                                'STORE need',
#                                'rip',
#                                'tostore manager',
#                                'tuff',
#                                'phone',
#                                'carriers']},
#                {'id': '3',
#                 'keyPhrases': ['service oriented service',
#                                'subpar service',
#                                'customer service',
#                                'tmobile store',
#                                'certain phones',
#                                'multiple phones',
#                                'bunch of phones',
#                                't-mobile store',
#                                'wrong rebates',
#                                'better job',
#                                'Im sure',
#                                'better version',
#                                'wrong paperwork',
#                                'terms of area coverage',
#                                'Cumberland Mall',
#                                "T's",
#                                "I's",
#                                'company',
#                                'proper rebate',
#                                'example',
#                                'serial numbers',
#                                'husband',
#                                'kids',
#                                'employees',
#                                'Sears',
#                                'attitudes',
#                                'girl',
#                                'help']},
#                {'id': '4',
#                 'keyPhrases': ['navigation systems',
#                                'simple question',
#                                'option',
#                                'roads',
#                                'phones',
#                                'young lady',
#                                'T-Mobile',
#                                'store',
#                                'answer',
#                                'point',
#                                'maps']},
#                {'id': '5',
#                 'keyPhrases': ['great customer service',
#                                'telephone customer service',
#                                'kashara',
#                                'rude employees',
#                                'contradictions',
#                                "i've",
#                                'different staff members',
#                                'tmobile',
#                                'didnt',
#                                'correct answer',
#                                'south cobb location',
#                                'question']}],
#  'errors': []}
# {'documents': [{'id': '1', 'score': 0.9700125455856323},
#                {'id': '2', 'score': 0.056124985218048096},
#                {'id': '3', 'score': 0.14918899536132812},
#                {'id': '4', 'score': 0.08946561813354492},
#                {'id': '5', 'score': 0.13647320866584778}],
#  'errors': []}
# Store: t-mobile-alpharetta-7
# Loc: 13
# Average Score: 3.200000
# BAD
# 14
# {'documents': [{'id': '1',
#                 'keyPhrases': ['T-Mobile employee',
#                                'new phone',
#                                'T-Mobile store',
#                                'old phone',
#                                'helpful apps',
#                                'smoke break right',
#                                'quickest way',
#                                'door',
#                                'info',
#                                'great services',
#                                'Good job',
#                                'ideal place',
#                                'employees',
#                                'customers',
#                                'area']},
#                {'id': '2',
#                 'keyPhrases': ['Best experience',
#                                'cellular carrier',
#                                'Brooke',
#                                'Patient']},
#                {'id': '3',
#                 'keyPhrases': ['unlocked phone',
#                                'quick SIM card switch',
#                                'smaller SIM card size',
#                                'old Motox SIM card slot',
#                                'proper working phone',
#                                'guy',
#                                'bad experience',
#                                'time',
#                                'following experience',
#                                'double check',
#                                'North Point Mall T-mobile store',
#                                'generation',
#                                'Samsung s4',
#                                'location',
#                                'good luck',
#                                'mistake',
#                                'attitude',
#                                'impression',
#                                'voice',
#                                'credibility',
#                                'blame',
#                                'reason',
#                                'process',
#                                'place',
#                                'smile',
#                                'hell',
#                                'friend',
#                                'Verizon',
#                                'GUESS',
#                                'ODD']},
#                {'id': '4',
#                 'keyPhrases': ['patient help thanks',
#                                'super cute attendant Brooke',
#                                'appreciated customer']},
#                {'id': '5',
#                 'keyPhrases': ['expensive charger',
#                                'purchase',
#                                'car charger ready',
#                                'negative experience',
#                                'location',
#                                'road',
#                                'sprint',
#                                'result',
#                                'good care',
#                                'reason',
#                                'discount']}],
#  'errors': [{'id': '3',
#              'message': 'Warning: The document contains very long words '
#                         '(longer than 64 characters). These words may result '
#                         'in truncated and/or unreliable model predictions.'}]}
# {'documents': [{'id': '1', 'score': 0.9662951231002808},
#                {'id': '2', 'score': 0.990606427192688},
#                {'id': '3', 'score': 0.06131643056869507},
#                {'id': '4', 'score': 0.9744153022766113},
#                {'id': '5', 'score': 0.8790883421897888}],
#  'errors': []}
# Store: t-mobile-atlanta-43
# Loc: 14
# Average Score: 3.000000
# HAPPY

# %%
import os
import nltk
from nltk import FreqDist
import pandas as pd
import matplotlib.pyplot as plt
import re
import requests
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_json('data.json')

# %%
subscription_key = 'c1005ffa18cc42ddbf916d2483bb2dd2'
assert subscription_key
text_analytics_base_url = "https://westcentralus.api.cognitive.microsoft.com/text/analytics/v2.0/"
# Out:
# environ({'TERM_PROGRAM_VERSION': '421', 'LOGNAME': 'jeffreyjacob', 'USER': 'jeffreyjacob', 'PATH': '/Library/Frameworks/Python.framework/Versions/3.7/bin:/Library/Frameworks/Python.framework/Versions/3.7/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/usr/local/share/dotnet:/opt/X11/bin:/Library/Frameworks/Mono.framework/Versions/Current/Commands:/Applications/Wireshark.app/Contents/MacOS:/usr/local/git/bin:/Applications/Xamarin Workbooks.app/Contents/SharedSupport/path-bin', 'HOME': '/Users/jeffreyjacob', 'DISPLAY': '/private/tmp/com.apple.launchd.YDKp4qa6eO/org.macosforge.xquartz:0', 'TERM_PROGRAM': 'Apple_Terminal', 'LANG': 'en_US.UTF-8', 'TERM': 'xterm-color', 'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.HZ5YnvhRQd/Render', 'SHLVL': '1', 'XPC_FLAGS': '0x0', 'TMPDIR': '/var/folders/2d/chc6k12d29dbdkdy3lg60d180000gn/T/', 'TERM_SESSION_ID': '79F44D52-2469-4D36-870E-9534F87EC16C', 'XPC_SERVICE_NAME': '0', 'JPY_PARENT_PID': '16814', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.lQQJTAizzS/Listeners', 'SHELL': '/bin/bash', '_': '/Library/Frameworks/Python.framework/Versions/3.7/bin/jupyter', 'OLDPWD': '/Users/jeffreyjacob/Documents/GitHub', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'PWD': '/Users/jeffreyjacob/Documents/GitHub/tmobile-hackathon', '__PYVENV_LAUNCHER__': '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'})
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-ad0a095967b5> in <module>
#       1 print(os.environ)
# ----> 2 subscription_key = os.environ['MS_KEY']
#       3 assert subscription_key
#       4 text_analytics_base_url = "https://westcentralus.api.cognitive.microsoft.com/text/analytics/v2.0/"
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'MS_KEY'

# %%
def freq_words(x, terms = 30):
  all_words = ' '.join([text for text in x])
  all_words = all_words.split()
  
  fdist = FreqDist(all_words)
  words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})
  
  # selecting top 20 most frequent words
  d = words_df.nlargest(columns="count", n = terms) 
  plt.figure(figsize=(20,5))
  ax = sns.barplot(data=d, x= "word", y = "count")
  ax.set(ylabel = 'Count')
  plt.show()

# %%
for i in range(len(df)):
    
    idnum = 1
    docDic = []
    for rev in raw_revs:
        docDic.append({'id':idnum, 'language':'en', 'text': rev[0]})
        idnum += 1
        
    documents = {'documents' : docDic}
    key_phrase_api_url = text_analytics_base_url + "keyPhrases"
    headers   = {'Ocp-Apim-Subscription-Key': subscription_key}
    response  = requests.post(key_phrase_api_url, headers=headers, json=documents)
    key_phrases = response.json()
    
    sentiment_api_url = text_analytics_base_url + "sentiment"
    response  = requests.post(sentiment_api_url, headers=headers, json=documents)
    sentiments = response.json()
    
    entity_linking_api_url = text_analytics_base_url + "entities"
    response  = requests.post(entity_linking_api_url, headers=headers, json=documents)
    entities = response.json()
    pprint(entities)
    
    keyphr = []
    senti = []
    try:
        for i in range(len(key_phrases['documents'])):
            keyphr += key_phrases['documents'][i]['keyPhrases']
            senti += [sentiments['documents'][i]['score']]
    except:
        pprint(key_phrases)
    
#     freq_words(keyphr)
    
    currStore = df.loc[i]['name']
    print("Store: " + currStore)
    print("Loc: " + str(i))
    raw_revs = df.loc[i]['reviews']
    scores = [rev[1] for rev in raw_revs]
    print ("Average Score: %f" % (sum(scores) / float(len(scores))))

#     if (sum(senti) / float(len(senti)) > 0.5):
#         print("HAPPY")
#     else:
#         print("BAD")
# Out:
# {'documents': [{'entities': [{'bingId': 'c9826276-77d7-c446-98c8-0d251f27cd70',
#                               'matches': [{'length': 14,
#                                            'offset': 98,
#                                            'text': 'Perimeter Mall'}],
#                               'name': 'Perimeter Mall',
#                               'wikipediaId': 'Perimeter Mall',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Perimeter_Mall'},
#                              {'bingId': 'db63aea8-3799-393d-678a-5f62c300d23d',
#                               'matches': [{'length': 10,
#                                            'offset': 343,
#                                            'text': 'MyTouch 4G'}],
#                               'name': 'T-Mobile myTouch 4G',
#                               'wikipediaId': 'T-Mobile myTouch 4G',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_myTouch_4G'},
#                              {'bingId': '7b69ac1d-d371-ea4d-a7f4-01c4a0d51d62',
#                               'matches': [{'length': 8,
#                                            'offset': 138,
#                                            'text': 'Dillards'}],
#                               'name': "Dillard's",
#                               'wikipediaId': "Dillard's",
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': "https://en.wikipedia.org/wiki/Dillard's"},
#                              {'bingId': '46f198ae-ea2f-2311-e397-75296d515199',
#                               'matches': [{'length': 7,
#                                            'offset': 589,
#                                            'text': "it's ME"}],
#                               'name': "It's Me (song)",
#                               'wikipediaId': "It's Me (song)",
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': "https://en.wikipedia.org/wiki/It's_Me_(song)"},
#                              {'bingId': '0337770e-8004-0323-5f43-7ca61f1170f2',
#                               'matches': [{'length': 7,
#                                            'offset': 3469,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 3978,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 83,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 2031,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 2125,
#                                            'text': 'TMobile'}],
#                               'name': 'T-Mobile',
#                               'wikipediaId': 'T-Mobile',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile'},
#                              {'bingId': '3793a6c0-f5d8-5e86-b9c9-5d9d385d01ff',
#                               'matches': [{'length': 7,
#                                            'offset': 1934,
#                                            'text': 'SD card'}],
#                               'name': 'Secure Digital',
#                               'wikipediaId': 'Secure Digital',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Secure_Digital'},
#                              {'bingId': 'a61739b4-0506-87f4-579f-91902e6368a7',
#                               'matches': [{'length': 6,
#                                            'offset': 3434,
#                                            'text': 'Mother'}],
#                               'name': 'Mother (drink)',
#                               'wikipediaId': 'Mother (drink)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Mother_(drink)'},
#                              {'bingId': '0cda4c14-dc45-ffcd-58b5-97ef884b77d2',
#                               'matches': [{'length': 5,
#                                            'offset': 2499,
#                                            'text': 'TODAY'}],
#                               'name': 'Today (U.S. TV program)',
#                               'wikipediaId': 'Today (U.S. TV program)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Today_(U.S._TV_program)'},
#                              {'bingId': '630f5f81-033c-e561-56af-680a87d2f8e2',
#                               'matches': [{'length': 5,
#                                            'offset': 1617,
#                                            'text': 'Super'}],
#                               'name': 'Super (2010 American film)',
#                               'wikipediaId': 'Super (2010 American film)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Super_(2010_American_film)'},
#                              {'bingId': '37d91d7f-a4da-a5e0-8e98-1a22b6e76f21',
#                               'matches': [{'length': 5,
#                                            'offset': 42,
#                                            'text': 'GRRRR'}],
#                               'name': 'Grrrr (song)',
#                               'wikipediaId': 'Grrrr (song)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Grrrr_(song)'},
#                              {'bingId': '5dccd0ef-d845-e25a-1fe6-16ae536bb51d',
#                               'matches': [{'length': 4,
#                                            'offset': 1421,
#                                            'text': 'BOTH'}],
#                               'name': 'Both (film)',
#                               'wikipediaId': 'Both (film)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Both_(film)'},
#                              {'bingId': 'd91bd89e-373d-543d-e789-e94f5e12e20d',
#                               'matches': [{'length': 4,
#                                            'offset': 1652,
#                                            'text': 'sh!t'}],
#                               'name': 'Shit',
#                               'wikipediaId': 'Shit',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Shit'}],
#                 'id': '1'},
#                {'entities': [{'bingId': 'c9826276-77d7-c446-98c8-0d251f27cd70',
#                               'matches': [{'length': 14,
#                                            'offset': 20,
#                                            'text': 'Perimeter mall'}],
#                               'name': 'Perimeter Mall',
#                               'wikipediaId': 'Perimeter Mall',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Perimeter_Mall'},
#                              {'bingId': '573218fc-f048-bb68-a877-fd7266cec74e',
#                               'matches': [{'length': 14,
#                                            'offset': 94,
#                                            'text': 'Secret shopper'}],
#                               'name': 'Mystery shopping',
#                               'wikipediaId': 'Mystery shopping',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Mystery_shopping'},
#                              {'bingId': '0337770e-8004-0323-5f43-7ca61f1170f2',
#                               'matches': [{'length': 7,
#                                            'offset': 8,
#                                            'text': 'Tmobile'}],
#                               'name': 'T-Mobile',
#                               'wikipediaId': 'T-Mobile',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile'}],
#                 'id': '2'},
#                {'entities': [{'bingId': 'c0b725d2-befc-df93-915e-dd0fc857a1a6',
#                               'matches': [{'length': 6,
#                                            'offset': 52,
#                                            'text': 'People'}],
#                               'name': 'People (magazine)',
#                               'wikipediaId': 'People (magazine)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/People_(magazine)'}],
#                 'id': '3'},
#                {'entities': [{'bingId': '35c58ae6-7bd6-5751-4ab1-a176fee6113d',
#                               'matches': [{'length': 13,
#                                            'offset': 207,
#                                            'text': 'the Perimeter'}],
#                               'name': 'Interstate 285 (Georgia)',
#                               'wikipediaId': 'Interstate 285 (Georgia)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Interstate_285_(Georgia)'},
#                              {'bingId': '37820268-d302-a8ab-043a-9c141b37c0f7',
#                               'matches': [{'length': 10,
#                                            'offset': 428,
#                                            'text': 'Mobile app'}],
#                               'name': 'Mobile app',
#                               'wikipediaId': 'Mobile app',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Mobile_app'},
#                              {'bingId': '377fb0d4-5d49-b4e7-afdd-a571f708782e',
#                               'matches': [{'length': 9,
#                                            'offset': 590,
#                                            'text': 'Thank you'}],
#                               'name': 'Thank You (Hellyeah song)',
#                               'wikipediaId': 'Thank You (Hellyeah song)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Thank_You_(Hellyeah_song)'},
#                              {'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 8,
#                                            'offset': 9,
#                                            'text': 'T-Mobile'},
#                                           {'length': 8,
#                                            'offset': 403,
#                                            'text': 'T-Mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'},
#                              {'bingId': '424cb54b-41a3-c86b-d8e0-3ecef5609ce8',
#                               'matches': [{'length': 7,
#                                            'offset': 475,
#                                            'text': 'Netflix'}],
#                               'name': 'Netflix',
#                               'wikipediaId': 'Netflix',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Netflix'},
#                              {'bingId': '56f1f198-84ea-263b-9412-b18bea13dd78',
#                               'matches': [{'length': 7,
#                                            'offset': 412,
#                                            'text': 'Tuesday'}],
#                               'name': 'Tuesday',
#                               'wikipediaId': 'Tuesday',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Tuesday'},
#                              {'bingId': 'aab65d69-d3a9-03aa-f203-a9732886463f',
#                               'matches': [{'length': 7,
#                                            'offset': 38,
#                                            'text': 'Verizon'}],
#                               'name': 'Verizon Communications',
#                               'wikipediaId': 'Verizon Communications',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Verizon_Communications'},
#                              {'bingId': 'c47da78b-4fdf-3297-761e-74439706bca1',
#                               'matches': [{'length': 5,
#                                            'offset': 422,
#                                            'text': 'The T'}],
#                               'name': 'Twitter',
#                               'wikipediaId': 'Twitter',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Twitter'},
#                              {'bingId': '8dc510e2-c8f4-5372-453b-8d2c4b348419',
#                               'matches': [{'length': 5,
#                                            'offset': 221,
#                                            'text': 'Store'}],
#                               'name': 'Retail',
#                               'wikipediaId': 'Retail',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Retail'},
#                              {'bingId': '56e7fe62-f94b-f86c-28d4-8f7db29c5e49',
#                               'matches': [{'length': 5,
#                                            'offset': 532,
#                                            'text': 'if We'}],
#                               'name': 'If(we)',
#                               'wikipediaId': 'If(we)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/If(we)'},
#                              {'bingId': 'f2061891-8558-29b1-4145-4b04babdabb7',
#                               'matches': [{'length': 4,
#                                            'offset': 60,
#                                            'text': 'I am'}],
#                               'name': 'I Am (2010 American documentary film)',
#                               'wikipediaId': 'I Am (2010 American documentary '
#                                              'film)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/I_Am_(2010_American_documentary_film)'},
#                              {'bingId': '9c644448-c8ad-e2d5-b569-0d25bc7d7848',
#                               'matches': [{'length': 4,
#                                            'offset': 562,
#                                            'text': 'Greg'},
#                                           {'length': 4,
#                                            'offset': 337,
#                                            'text': 'Greg'},
#                                           {'length': 4,
#                                            'offset': 627,
#                                            'text': 'Greg'}],
#                               'name': 'Greg Sanders',
#                               'wikipediaId': 'Greg Sanders',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Greg_Sanders'}],
#                 'id': '4'},
#                {'entities': [{'bingId': 'aabdfc85-5c81-5ece-793f-f5d9358040ba',
#                               'matches': [{'length': 8,
#                                            'offset': 236,
#                                            'text': 'SIM card'}],
#                               'name': 'Subscriber identity module',
#                               'wikipediaId': 'Subscriber identity module',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Subscriber_identity_module'},
#                              {'bingId': '0cda4c14-dc45-ffcd-58b5-97ef884b77d2',
#                               'matches': [{'length': 5,
#                                            'offset': 246,
#                                            'text': 'Today'}],
#                               'name': 'Today (U.S. TV program)',
#                               'wikipediaId': 'Today (U.S. TV program)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Today_(U.S._TV_program)'}],
#                 'id': '5'},
#                {'entities': [{'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 8,
#                                            'offset': 363,
#                                            'text': 'T-Mobile'},
#                                           {'length': 8,
#                                            'offset': 109,
#                                            'text': 'T-mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'},
#                              {'bingId': '63f428d4-f1c2-4d9a-82ab-c1e645f13adf',
#                               'matches': [{'length': 8,
#                                            'offset': 588,
#                                            'text': 'CHARGERS'},
#                                           {'length': 8,
#                                            'offset': 503,
#                                            'text': 'CHARGERS'}],
#                               'name': 'Los Angeles Chargers',
#                               'wikipediaId': 'Los Angeles Chargers',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Los_Angeles_Chargers'},
#                              {'bingId': 'd05244be-98d8-522a-364a-5f8fc159392a',
#                               'matches': [{'length': 7,
#                                            'offset': 166,
#                                            'text': 'Samsung'}],
#                               'name': 'Samsung Electronics',
#                               'wikipediaId': 'Samsung Electronics',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Samsung_Electronics'},
#                              {'bingId': '2785f3a0-fac2-fc86-bebb-b9bb286bb45f',
#                               'matches': [{'length': 7,
#                                            'offset': 489,
#                                            'text': 'SAMSUNG'}],
#                               'name': 'Samsung',
#                               'wikipediaId': 'Samsung',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Samsung'},
#                              {'bingId': 'e8af157c-d4f8-2571-2f4c-4f00224d072e',
#                               'matches': [{'length': 6,
#                                            'offset': 581,
#                                            'text': 'BELKIN'}],
#                               'name': 'Belkin',
#                               'wikipediaId': 'Belkin',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Belkin'},
#                              {'bingId': 'ce00286a-e903-ff2c-7dac-b49bd707399c',
#                               'matches': [{'length': 6,
#                                            'offset': 314,
#                                            'text': 'Amazon'}],
#                               'name': 'Amazon (company)',
#                               'wikipediaId': 'Amazon (company)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Amazon_(company)'},
#                              {'bingId': '0854be60-66b6-b783-25b6-b60fad1d906b',
#                               'matches': [{'length': 4,
#                                            'offset': 322,
#                                            'text': 'PLUS'}],
#                               'name': 'Plus (supermarket)',
#                               'wikipediaId': 'Plus (supermarket)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Plus_(supermarket)'}],
#                 'id': '6'},
#                {'entities': [{'bingId': 'c9826276-77d7-c446-98c8-0d251f27cd70',
#                               'matches': [{'length': 14,
#                                            'offset': 35,
#                                            'text': 'Perimeter Mall'}],
#                               'name': 'Perimeter Mall',
#                               'wikipediaId': 'Perimeter Mall',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Perimeter_Mall'},
#                              {'bingId': '7b69ac1d-d371-ea4d-a7f4-01c4a0d51d62',
#                               'matches': [{'length': 8,
#                                            'offset': 76,
#                                            'text': 'Dillards'}],
#                               'name': "Dillard's",
#                               'wikipediaId': "Dillard's",
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': "https://en.wikipedia.org/wiki/Dillard's"},
#                              {'bingId': 'e055a524-b730-f38c-074d-c0174dfe31bc',
#                               'matches': [{'length': 6,
#                                            'offset': 338,
#                                            'text': 'Renata'}],
#                               'name': 'Renata (battery)',
#                               'wikipediaId': 'Renata (battery)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Renata_(battery)'},
#                              {'bingId': '845219d5-3650-4199-b926-964ca27c863c',
#                               'matches': [{'length': 2,
#                                            'offset': 579,
#                                            'text': 'Ma'}],
#                               'name': 'Massachusetts',
#                               'wikipediaId': 'Massachusetts',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Massachusetts'}],
#                 'id': '7'},
#                {'entities': [{'bingId': '6fc728bc-3ac0-6688-46be-2218f459a9c2',
#                               'matches': [{'length': 4,
#                                            'offset': 45,
#                                            'text': 'Shor'}],
#                               'name': 'Toots Shor',
#                               'wikipediaId': 'Toots Shor',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Toots_Shor'}],
#                 'id': '8'}],
#  'errors': []}
# Store: t-mobile-atlanta-46
# Loc: 7
# Average Score: 3.142857
# {'documents': [{'entities': [{'bingId': '480b9330-1f17-8cbf-7469-bf9f560decf4',
#                               'matches': [{'length': 20,
#                                            'offset': 235,
#                                            'text': 'I-85 bridge collapse'}],
#                               'name': 'Interstate 85 bridge collapse',
#                               'wikipediaId': 'Interstate 85 bridge collapse',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Interstate_85_bridge_collapse'},
#                              {'bingId': '75d2893f-8181-2598-e5a7-73efc711e32a',
#                               'matches': [{'length': 14,
#                                            'offset': 608,
#                                            'text': 'Chinese buffet'}],
#                               'name': 'American Chinese cuisine',
#                               'wikipediaId': 'American Chinese cuisine',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/American_Chinese_cuisine'},
#                              {'bingId': '9ca75e47-39af-2775-a2f4-d2947e49bb59',
#                               'matches': [{'length': 13,
#                                            'offset': 943,
#                                            'text': 'iPhone 7 Plus'}],
#                               'name': 'IPhone 7',
#                               'wikipediaId': 'IPhone 7',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/IPhone_7'},
#                              {'bingId': '4663d5f4-6b74-b71e-7254-39a9f224931d',
#                               'matches': [{'length': 13,
#                                            'offset': 260,
#                                            'text': 'iPhone 6 Plus'}],
#                               'name': 'IPhone 6',
#                               'wikipediaId': 'IPhone 6',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/IPhone_6'},
#                              {'bingId': '98dde534-577e-e050-682d-8c67c28d3e13',
#                               'matches': [{'length': 10,
#                                            'offset': 397,
#                                            'text': 'Plug it in'}],
#                               'name': 'Plug It In (song)',
#                               'wikipediaId': 'Plug It In (song)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Plug_It_In_(song)'},
#                              {'bingId': 'ccaa1eaa-b691-86cb-458f-0c4c624b4dca',
#                               'matches': [{'length': 9,
#                                            'offset': 630,
#                                            'text': 'UPS store'}],
#                               'name': 'The UPS Store',
#                               'wikipediaId': 'The UPS Store',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/The_UPS_Store'},
#                              {'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 8,
#                                            'offset': 45,
#                                            'text': 'T-Mobile'},
#                                           {'length': 8,
#                                            'offset': 1306,
#                                            'text': 'T-Mobile'},
#                                           {'length': 8,
#                                            'offset': 524,
#                                            'text': 'T-Mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'},
#                              {'bingId': 'ee2f9f7d-b77e-4818-a73a-3425b22ba284',
#                               'matches': [{'length': 8,
#                                            'offset': 830,
#                                            'text': 'Jonathan'}],
#                               'name': 'Jonathan (1 Samuel)',
#                               'wikipediaId': 'Jonathan (1 Samuel)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Jonathan_(1_Samuel)'},
#                              {'bingId': 'e1acd984-fc55-7626-5a48-e87c1ecdf3c7',
#                               'matches': [{'length': 7,
#                                            'offset': 1288,
#                                            'text': 'Verizon'}],
#                               'name': 'Verizon Wireless',
#                               'wikipediaId': 'Verizon Wireless',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Verizon_Wireless'},
#                              {'bingId': '4fe14df6-d63f-93e5-3032-b0e7050bca8c',
#                               'matches': [{'length': 7,
#                                            'offset': 211,
#                                            'text': 'Youtube'}],
#                               'name': 'YouTube',
#                               'wikipediaId': 'YouTube',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/YouTube'},
#                              {'bingId': 'b5e7bb5e-873f-9785-a79b-745812d0c36f',
#                               'matches': [{'length': 7,
#                                            'offset': 289,
#                                            'text': 'Methods'}],
#                               'name': 'Method (computer programming)',
#                               'wikipediaId': 'Method (computer programming)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Method_(computer_programming)'},
#                              {'bingId': 'c585a48c-021b-bfdd-edd6-56b3d45ad8ae',
#                               'matches': [{'length': 6,
#                                            'offset': 1277,
#                                            'text': 'Spring'}],
#                               'name': 'Spring (operating system)',
#                               'wikipediaId': 'Spring (operating system)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Spring_(operating_system)'},
#                              {'bingId': 'ffa7568d-e185-43ab-a812-3dafa22b0b1d',
#                               'matches': [{'length': 5,
#                                            'offset': 376,
#                                            'text': 'Power'}],
#                               'name': 'Power (TV series)',
#                               'wikipediaId': 'Power (TV series)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Power_(TV_series)'},
#                              {'bingId': 'e6a71ded-a23c-1976-ccdd-14a44023e382',
#                               'matches': [{'length': 5,
#                                            'offset': 886,
#                                            'text': 'After'}],
#                               'name': 'After (Lady Lamb album)',
#                               'wikipediaId': 'After (Lady Lamb album)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/After_(Lady_Lamb_album)'},
#                              {'bingId': '19e3119d-6f9d-849d-35c8-2c7c3f05d8bd',
#                               'matches': [{'length': 5,
#                                            'offset': 62,
#                                            'text': 'And I'}],
#                               'name': 'And I',
#                               'wikipediaId': 'And I',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/And_I'},
#                              {'bingId': '5288e6b2-094a-9e72-d584-2ccbc1c2eb88',
#                               'matches': [{'length': 5,
#                                            'offset': 141,
#                                            'text': 'Asian'}],
#                               'name': 'Asia',
#                               'wikipediaId': 'Asia',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Asia'},
#                              {'bingId': 'c46a8e31-b590-87b8-b72d-2df01e863c19',
#                               'matches': [{'length': 4,
#                                            'offset': 1271,
#                                            'text': 'AT&T'}],
#                               'name': 'AT&T',
#                               'wikipediaId': 'AT&T',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/AT&T'},
#                              {'bingId': '87eac31c-8f31-5d8a-e47c-33b7d246c77b',
#                               'matches': [{'length': 4,
#                                            'offset': 1155,
#                                            'text': 'ASAP'}],
#                               'name': 'ASAP (TV program)',
#                               'wikipediaId': 'ASAP (TV program)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/ASAP_(TV_program)'},
#                              {'bingId': '134e9f41-ff24-9768-8bfa-12d66b0b8a39',
#                               'matches': [{'length': 4,
#                                            'offset': 961,
#                                            'text': 'Area'}],
#                               'name': 'Area',
#                               'wikipediaId': 'Area',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Area'},
#                              {'bingId': '40cdeb36-b9b1-0a3b-0699-03bde96d8087',
#                               'matches': [{'length': 3,
#                                            'offset': 826,
#                                            'text': 'Mr.'}],
#                               'name': 'Mr.',
#                               'wikipediaId': 'Mr.',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Mr.'}],
#                 'id': '1'},
#                {'entities': [], 'id': '2'},
#                {'entities': [{'bingId': 'f2bfcc45-a8a2-c16d-9b7c-b2517ba722af',
#                               'matches': [{'length': 9,
#                                            'offset': 17,
#                                            'text': 'Galaxy S5'}],
#                               'name': 'Samsung Galaxy S5',
#                               'wikipediaId': 'Samsung Galaxy S5',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Samsung_Galaxy_S5'},
#                              {'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 9,
#                                            'offset': 995,
#                                            'text': 'T- Mobile'},
#                                           {'length': 8,
#                                            'offset': 810,
#                                            'text': 'T-Mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'},
#                              {'bingId': '1914ab05-d311-6bf2-96d0-64a3dae6b5b9',
#                               'matches': [{'length': 7,
#                                            'offset': 673,
#                                            'text': 'JUMP to'}],
#                               'name': 'Goto',
#                               'wikipediaId': 'Goto',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Goto'},
#                              {'bingId': 'c0b725d2-befc-df93-915e-dd0fc857a1a6',
#                               'matches': [{'length': 6,
#                                            'offset': 777,
#                                            'text': 'People'}],
#                               'name': 'People (magazine)',
#                               'wikipediaId': 'People (magazine)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/People_(magazine)'},
#                              {'bingId': '9e9d601e-a8a2-dbc0-defd-e7046a469661',
#                               'matches': [{'length': 5,
#                                            'offset': 358,
#                                            'text': 'Shawn'},
#                                           {'length': 5,
#                                            'offset': 436,
#                                            'text': 'Shawn'}],
#                               'name': 'Shawn Spencer',
#                               'wikipediaId': 'Shawn Spencer',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Shawn_Spencer'},
#                              {'bingId': '0cda4c14-dc45-ffcd-58b5-97ef884b77d2',
#                               'matches': [{'length': 5,
#                                            'offset': 1030,
#                                            'text': 'Today'}],
#                               'name': 'Today (U.S. TV program)',
#                               'wikipediaId': 'Today (U.S. TV program)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Today_(U.S._TV_program)'},
#                              {'bingId': 'd7e70df7-052b-acc1-7640-d9893c08eda9',
#                               'matches': [{'length': 2,
#                                            'offset': 687,
#                                            'text': 'S6'}],
#                               'name': 'Samsung Galaxy S6',
#                               'wikipediaId': 'Samsung Galaxy S6',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Samsung_Galaxy_S6'}],
#                 'id': '3'},
#                {'entities': [{'bingId': 'fc9965da-a55e-5895-02e5-f0e78bfa32ac',
#                               'matches': [{'length': 5,
#                                            'offset': 50,
#                                            'text': 'David'}],
#                               'name': 'DAVID',
#                               'wikipediaId': 'DAVID',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/DAVID'}],
#                 'id': '4'},
#                {'entities': [{'bingId': 'd0629d89-8c66-649f-bf15-08f275429b5b',
#                               'matches': [{'length': 9,
#                                            'offset': 349,
#                                            'text': 'Thank you'}],
#                               'name': 'Thank You (1925 film)',
#                               'wikipediaId': 'Thank You (1925 film)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Thank_You_(1925_film)'},
#                              {'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 8,
#                                            'offset': 33,
#                                            'text': 'T-mobile'},
#                                           {'length': 8,
#                                            'offset': 359,
#                                            'text': 'T-mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'}],
#                 'id': '5'},
#                {'entities': [{'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 8,
#                                            'offset': 237,
#                                            'text': 'T mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'}],
#                 'id': '6'},
#                {'entities': [{'bingId': '5c3e4efd-192c-2531-845f-440a7b7f44f9',
#                               'matches': [{'length': 7,
#                                            'offset': 368,
#                                            'text': 'Comcast'}],
#                               'name': 'Comcast',
#                               'wikipediaId': 'Comcast',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Comcast'},
#                              {'bingId': '2f6c5857-6dc8-3f68-3dbc-497c95cbc2ae',
#                               'matches': [{'length': 7,
#                                            'offset': 647,
#                                            'text': 'comcast'}],
#                               'name': 'Xfinity',
#                               'wikipediaId': 'Xfinity',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Xfinity'},
#                              {'bingId': '4f4dd970-d7dc-c1fb-5fbc-915bcdfb594f',
#                               'matches': [{'length': 5,
#                                            'offset': 15,
#                                            'text': 'Raven'}],
#                               'name': 'Raven (DC Comics)',
#                               'wikipediaId': 'Raven (DC Comics)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Raven_(DC_Comics)'},
#                              {'bingId': '95174ca5-7026-4486-8e73-c60a2ce40a31',
#                               'matches': [{'length': 4,
#                                            'offset': 742,
#                                            'text': 'I am'}],
#                               'name': 'I Am (2010 Indian film)',
#                               'wikipediaId': 'I Am (2010 Indian film)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/I_Am_(2010_Indian_film)'},
#                              {'bingId': 'c46a8e31-b590-87b8-b72d-2df01e863c19',
#                               'matches': [{'length': 4,
#                                            'offset': 786,
#                                            'text': 'AT&T'}],
#                               'name': 'AT&T',
#                               'wikipediaId': 'AT&T',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/AT&T'}],
#                 'id': '7'}],
#  'errors': []}
# Store: t-mobile-atlanta-23
# Loc: 6
# Average Score: 2.000000
# {'documents': [{'entities': [{'bingId': 'c9826276-77d7-c446-98c8-0d251f27cd70',
#                               'matches': [{'length': 14,
#                                            'offset': 98,
#                                            'text': 'Perimeter Mall'}],
#                               'name': 'Perimeter Mall',
#                               'wikipediaId': 'Perimeter Mall',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Perimeter_Mall'},
#                              {'bingId': 'db63aea8-3799-393d-678a-5f62c300d23d',
#                               'matches': [{'length': 10,
#                                            'offset': 343,
#                                            'text': 'MyTouch 4G'}],
#                               'name': 'T-Mobile myTouch 4G',
#                               'wikipediaId': 'T-Mobile myTouch 4G',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_myTouch_4G'},
#                              {'bingId': '7b69ac1d-d371-ea4d-a7f4-01c4a0d51d62',
#                               'matches': [{'length': 8,
#                                            'offset': 138,
#                                            'text': 'Dillards'}],
#                               'name': "Dillard's",
#                               'wikipediaId': "Dillard's",
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': "https://en.wikipedia.org/wiki/Dillard's"},
#                              {'bingId': '46f198ae-ea2f-2311-e397-75296d515199',
#                               'matches': [{'length': 7,
#                                            'offset': 589,
#                                            'text': "it's ME"}],
#                               'name': "It's Me (song)",
#                               'wikipediaId': "It's Me (song)",
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': "https://en.wikipedia.org/wiki/It's_Me_(song)"},
#                              {'bingId': '0337770e-8004-0323-5f43-7ca61f1170f2',
#                               'matches': [{'length': 7,
#                                            'offset': 3469,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 3978,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 83,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 2031,
#                                            'text': 'TMobile'},
#                                           {'length': 7,
#                                            'offset': 2125,
#                                            'text': 'TMobile'}],
#                               'name': 'T-Mobile',
#                               'wikipediaId': 'T-Mobile',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile'},
#                              {'bingId': '3793a6c0-f5d8-5e86-b9c9-5d9d385d01ff',
#                               'matches': [{'length': 7,
#                                            'offset': 1934,
# ...
#                                            'offset': 211,
#                                            'text': 'Youtube'}],
#                               'name': 'YouTube',
#                               'wikipediaId': 'YouTube',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/YouTube'},
#                              {'bingId': 'b5e7bb5e-873f-9785-a79b-745812d0c36f',
#                               'matches': [{'length': 7,
#                                            'offset': 289,
#                                            'text': 'Methods'}],
#                               'name': 'Method (computer programming)',
#                               'wikipediaId': 'Method (computer programming)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Method_(computer_programming)'},
#                              {'bingId': 'c585a48c-021b-bfdd-edd6-56b3d45ad8ae',
#                               'matches': [{'length': 6,
#                                            'offset': 1277,
#                                            'text': 'Spring'}],
#                               'name': 'Spring (operating system)',
#                               'wikipediaId': 'Spring (operating system)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Spring_(operating_system)'},
#                              {'bingId': 'ffa7568d-e185-43ab-a812-3dafa22b0b1d',
#                               'matches': [{'length': 5,
#                                            'offset': 376,
#                                            'text': 'Power'}],
#                               'name': 'Power (TV series)',
#                               'wikipediaId': 'Power (TV series)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Power_(TV_series)'},
#                              {'bingId': 'e6a71ded-a23c-1976-ccdd-14a44023e382',
#                               'matches': [{'length': 5,
#                                            'offset': 886,
#                                            'text': 'After'}],
#                               'name': 'After (Lady Lamb album)',
#                               'wikipediaId': 'After (Lady Lamb album)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/After_(Lady_Lamb_album)'},
#                              {'bingId': '19e3119d-6f9d-849d-35c8-2c7c3f05d8bd',
#                               'matches': [{'length': 5,
#                                            'offset': 62,
#                                            'text': 'And I'}],
#                               'name': 'And I',
#                               'wikipediaId': 'And I',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/And_I'},
#                              {'bingId': '5288e6b2-094a-9e72-d584-2ccbc1c2eb88',
#                               'matches': [{'length': 5,
#                                            'offset': 141,
#                                            'text': 'Asian'}],
#                               'name': 'Asia',
#                               'wikipediaId': 'Asia',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Asia'},
#                              {'bingId': 'c46a8e31-b590-87b8-b72d-2df01e863c19',
#                               'matches': [{'length': 4,
#                                            'offset': 1271,
#                                            'text': 'AT&T'}],
#                               'name': 'AT&T',
#                               'wikipediaId': 'AT&T',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/AT&T'},
#                              {'bingId': '87eac31c-8f31-5d8a-e47c-33b7d246c77b',
#                               'matches': [{'length': 4,
#                                            'offset': 1155,
#                                            'text': 'ASAP'}],
#                               'name': 'ASAP (TV program)',
#                               'wikipediaId': 'ASAP (TV program)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/ASAP_(TV_program)'},
#                              {'bingId': '134e9f41-ff24-9768-8bfa-12d66b0b8a39',
#                               'matches': [{'length': 4,
#                                            'offset': 961,
#                                            'text': 'Area'}],
#                               'name': 'Area',
#                               'wikipediaId': 'Area',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Area'},
#                              {'bingId': '40cdeb36-b9b1-0a3b-0699-03bde96d8087',
#                               'matches': [{'length': 3,
#                                            'offset': 826,
#                                            'text': 'Mr.'}],
#                               'name': 'Mr.',
#                               'wikipediaId': 'Mr.',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Mr.'}],
#                 'id': '1'},
#                {'entities': [], 'id': '2'},
#                {'entities': [{'bingId': 'f2bfcc45-a8a2-c16d-9b7c-b2517ba722af',
#                               'matches': [{'length': 9,
#                                            'offset': 17,
#                                            'text': 'Galaxy S5'}],
#                               'name': 'Samsung Galaxy S5',
#                               'wikipediaId': 'Samsung Galaxy S5',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Samsung_Galaxy_S5'},
#                              {'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 9,
#                                            'offset': 995,
#                                            'text': 'T- Mobile'},
#                                           {'length': 8,
#                                            'offset': 810,
#                                            'text': 'T-Mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'},
#                              {'bingId': '1914ab05-d311-6bf2-96d0-64a3dae6b5b9',
#                               'matches': [{'length': 7,
#                                            'offset': 673,
#                                            'text': 'JUMP to'}],
#                               'name': 'Goto',
#                               'wikipediaId': 'Goto',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Goto'},
#                              {'bingId': 'c0b725d2-befc-df93-915e-dd0fc857a1a6',
#                               'matches': [{'length': 6,
#                                            'offset': 777,
#                                            'text': 'People'}],
#                               'name': 'People (magazine)',
#                               'wikipediaId': 'People (magazine)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/People_(magazine)'},
#                              {'bingId': '9e9d601e-a8a2-dbc0-defd-e7046a469661',
#                               'matches': [{'length': 5,
#                                            'offset': 358,
#                                            'text': 'Shawn'},
#                                           {'length': 5,
#                                            'offset': 436,
#                                            'text': 'Shawn'}],
#                               'name': 'Shawn Spencer',
#                               'wikipediaId': 'Shawn Spencer',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Shawn_Spencer'},
#                              {'bingId': '0cda4c14-dc45-ffcd-58b5-97ef884b77d2',
#                               'matches': [{'length': 5,
#                                            'offset': 1030,
#                                            'text': 'Today'}],
#                               'name': 'Today (U.S. TV program)',
#                               'wikipediaId': 'Today (U.S. TV program)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Today_(U.S._TV_program)'},
#                              {'bingId': 'd7e70df7-052b-acc1-7640-d9893c08eda9',
#                               'matches': [{'length': 2,
#                                            'offset': 687,
#                                            'text': 'S6'}],
#                               'name': 'Samsung Galaxy S6',
#                               'wikipediaId': 'Samsung Galaxy S6',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Samsung_Galaxy_S6'}],
#                 'id': '3'},
#                {'entities': [{'bingId': 'fc9965da-a55e-5895-02e5-f0e78bfa32ac',
#                               'matches': [{'length': 5,
#                                            'offset': 50,
#                                            'text': 'David'}],
#                               'name': 'DAVID',
#                               'wikipediaId': 'DAVID',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/DAVID'}],
#                 'id': '4'},
#                {'entities': [{'bingId': 'd0629d89-8c66-649f-bf15-08f275429b5b',
#                               'matches': [{'length': 9,
#                                            'offset': 349,
#                                            'text': 'Thank you'}],
#                               'name': 'Thank You (1925 film)',
#                               'wikipediaId': 'Thank You (1925 film)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Thank_You_(1925_film)'},
#                              {'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 8,
#                                            'offset': 33,
#                                            'text': 'T-mobile'},
#                                           {'length': 8,
#                                            'offset': 359,
#                                            'text': 'T-mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'}],
#                 'id': '5'},
#                {'entities': [{'bingId': '3d449f2f-d7b9-2425-7362-f5e131098910',
#                               'matches': [{'length': 8,
#                                            'offset': 237,
#                                            'text': 'T mobile'}],
#                               'name': 'T-Mobile US',
#                               'wikipediaId': 'T-Mobile US',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/T-Mobile_US'}],
#                 'id': '6'},
#                {'entities': [{'bingId': '5c3e4efd-192c-2531-845f-440a7b7f44f9',
#                               'matches': [{'length': 7,
#                                            'offset': 368,
#                                            'text': 'Comcast'}],
#                               'name': 'Comcast',
#                               'wikipediaId': 'Comcast',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Comcast'},
#                              {'bingId': '2f6c5857-6dc8-3f68-3dbc-497c95cbc2ae',
#                               'matches': [{'length': 7,
#                                            'offset': 647,
#                                            'text': 'comcast'}],
#                               'name': 'Xfinity',
#                               'wikipediaId': 'Xfinity',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Xfinity'},
#                              {'bingId': '4f4dd970-d7dc-c1fb-5fbc-915bcdfb594f',
#                               'matches': [{'length': 5,
#                                            'offset': 15,
#                                            'text': 'Raven'}],
#                               'name': 'Raven (DC Comics)',
#                               'wikipediaId': 'Raven (DC Comics)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/Raven_(DC_Comics)'},
#                              {'bingId': '95174ca5-7026-4486-8e73-c60a2ce40a31',
#                               'matches': [{'length': 4,
#                                            'offset': 742,
#                                            'text': 'I am'}],
#                               'name': 'I Am (2010 Indian film)',
#                               'wikipediaId': 'I Am (2010 Indian film)',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/I_Am_(2010_Indian_film)'},
#                              {'bingId': 'c46a8e31-b590-87b8-b72d-2df01e863c19',
#                               'matches': [{'length': 4,
#                                            'offset': 786,
#                                            'text': 'AT&T'}],
#                               'name': 'AT&T',
#                               'wikipediaId': 'AT&T',
#                               'wikipediaLanguage': 'en',
#                               'wikipediaUrl': 'https://en.wikipedia.org/wiki/AT&T'}],
#                 'id': '7'}],
#  'errors': []}
# Store: t-mobile-atlanta-23
# Loc: 6
# Average Score: 2.000000
# {'message': 'Rate limit is exceeded. Try again in 45 seconds.',
#  'statusCode': 429}
# {'message': 'Rate limit is exceeded. Try again in 45 seconds.',
#  'statusCode': 429}
# Store: t-mobile-east-point
# Loc: 10
# Average Score: 1.833333
# {'message': 'Rate limit is exceeded. Try again in 44 seconds.',
#  'statusCode': 429}
# {'message': 'Rate limit is exceeded. Try again in 45 seconds.',
#  'statusCode': 429}
# Store: t-mobile-atlanta-35
# Loc: 11
# Average Score: 4.000000
# {'message': 'Rate limit is exceeded. Try again in 44 seconds.',
#  'statusCode': 429}
# {'message': 'Rate limit is exceeded. Try again in 44 seconds.',
#  'statusCode': 429}
# Store: t-mobile-atlanta-28
# Loc: 12
# Average Score: 2.600000
# {'message': 'Rate limit is exceeded. Try again in 43 seconds.',
#  'statusCode': 429}
# {'message': 'Rate limit is exceeded. Try again in 43 seconds.',
#  'statusCode': 429}
# Store: t-mobile-alpharetta-7
# Loc: 13
# Average Score: 3.200000
# {'message': 'Rate limit is exceeded. Try again in 42 seconds.',
#  'statusCode': 429}
# {'message': 'Rate limit is exceeded. Try again in 43 seconds.',
#  'statusCode': 429}
# Store: t-mobile-atlanta-43
# Loc: 14
# Average Score: 3.000000
